# %%
from scipy.stats import multivariate_normal
from random import randint
import numpy as np

# %%
x, y = [], []
file = open("3gaussian.txt", 'r')
k = 3
for line in file:
    x.append(float(line.split()[0]))
    y.append(float(line.split()[1]))

# %%
u = [[2,2], [6,3], [4,6]]
cov_mat = [[[1,0],[0,2]], [[1,0.9], [0.9,1]], [[1, 0.9], [0.9, 1]]]
weights = {0: 0.323, 1: 0.328, 2: 0.349}
pi_0 = {}
pi_1 = {}
pi_2 = {}

# %%
def probablity(data_point, u, cov_mat):
    var = multivariate_normal(mean=u, cov=cov_mat)
    prob = var.pdf([data_point[0], data_point[1]])
    return prob

# %%
def expectation():
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        probs = []
        for j in range(0, k):
            prob = probablity(data_point, u[j], cov_mat[j])
            if j == 0:
                pi_0[data_point] = prob * weights[0]
            elif j == 1:
                pi_1[data_point] = prob * weights[1]
            else:
                pi_2[data_point] = prob * weights[2]
            probs.append((prob, j))
        denom = 0
        for prob in probs:
            label = prob[1]
            denom += prob[0] * weights[label]

        pi_0[data_point] /= denom
        pi_1[data_point] /= denom
        pi_2[data_point] /= denom

# %%
def maximization():
    weights[0] = sum(list(pi_0.values())) / len(x)
    weights[1] = sum(list(pi_1.values())) / len(x)
    weights[2] = sum(list(pi_2.values())) / len(x)
    sum_u0_x = 0
    sum_u0_y = 0
    sum_u1_x = 0
    sum_u1_y = 0
    sum_u2_x = 0
    sum_u2_y = 0
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        p0 = pi_0[data_point]
        p1 = pi_1[data_point]
        p2 = pi_2[data_point]
        sum_u0_x += (p0 * x[i])
        sum_u0_y += (p0 * y[i])
        sum_u1_x += (p1 * x[i])
        sum_u1_y += (p1 * y[i])
        sum_u2_x += (p2 * x[i])
        sum_u2_y += (p2 * y[i])
    sum_u0_x /= sum(list(pi_0.values()))
    sum_u0_y /= sum(list(pi_0.values()))
    sum_u1_x /= sum(list(pi_1.values()))
    sum_u1_y /= sum(list(pi_1.values()))
    sum_u2_x /= sum(list(pi_2.values()))
    sum_u2_y /= sum(list(pi_2.values()))
    u[0][0] = sum_u0_x
    u[0][1] = sum_u0_y
    u[1][0] = sum_u1_x
    u[1][1] = sum_u1_y
    u[2][0] = sum_u2_x
    u[2][1] = sum_u2_y
    update_cov_mat()

# %%
def update_cov_mat():
    final_cov_mat0 = [[0,0], [0,0]]
    final_cov_mat1 = [[0,0], [0,0]]
    final_cov_mat2 = [[0,0], [0,0]]
    for i in range(len(x)):
        data_point = (x[i], y[i])
        prob0 = pi_0[data_point]
        prob1 = pi_1[data_point]
        prob2 = pi_2[data_point]
        
        factor01 = [data_point[0] - u[0][0], data_point[1] - u[0][1]]
        factor01 = np.array(factor01).reshape(1,-1)
        factor02 = np.dot(factor01.reshape(-1,1), factor01)
        factor03 = prob0 * factor02
        
        for m in range(2):
            for n in range(2):
                final_cov_mat0[m][n] += factor03[m][n]
        
        factor11 = [data_point[0] - u[1][0], data_point[1] - u[1][1]]
        factor11 = np.array(factor11).reshape(1,-1)
        factor12 = np.dot(factor11.reshape(-1,1), factor11)
        factor13 = prob1 * factor12
        
        for m in range(2):
            for n in range(2):
                final_cov_mat1[m][n] += factor13[m][n]
                
        factor21 = [data_point[0] - u[2][0], data_point[1] - u[2][1]]
        factor21 = np.array(factor21).reshape(1,-1)
        factor22 = np.dot(factor21.reshape(-1,1), factor21)
        factor23 = prob2 * factor22
        
        for m in range(2):
            for n in range(2):
                final_cov_mat2[m][n] += factor23[m][n]
                
    for m in range(2):
        for n in range(2):
            final_cov_mat0[m][n] = final_cov_mat0[m][n] / sum(list(pi_0.values()))
    
    for m in range(2):
        for n in range(2):
            final_cov_mat1[m][n] = final_cov_mat1[m][n] / sum(list(pi_1.values()))
    
    for m in range(2):
        for n in range(2):
            final_cov_mat2[m][n] = final_cov_mat2[m][n] / sum(list(pi_2.values()))
    
    cov_mat[0] = final_cov_mat0
    cov_mat[1] = final_cov_mat1
    cov_mat[2] = final_cov_mat2

# %%
def repeat_untill_convergence():
    i = 0
    while(i <= 76):
        print("Iteration: " + str(i))
        expectation()
        print("Expectation done")
        maximization()
        print("Maximization done")
        print("Mean 1: ", end = " ")
        print(u[0])
        print("Mean 2: ", end = " ")
        print(u[1])
        print("Mean 3: ", end = " ")
        print(u[2])
        print("Covariance 1: ", end = " ")
        print(cov_mat[0])
        print("Covariance 2: ", end = " ")
        print(cov_mat[1])
        print("Covariance 3: ", end = " ")
        print(cov_mat[2])
        print("Weights: ", end = " ")
        print(weights)
        print("=============================================")
        i += 1

# %%
repeat_untill_convergence()
# Out:
# Iteration: 0
# Expectation done
# Maximization done
# Mean 1:  [3.0467196929962985, 3.068441005334694]
# Mean 2:  [7.023023844002468, 4.016252672978351]
# Mean 3:  [5.0151562494154565, 7.004494408688037]
# Covariance 1:  [[1.0339262584171014, 0.04006820509665956], [0.04006820509665956, 3.425157522432528]]
# Covariance 2:  [[0.9879446413012476, 0.5000187755321673], [0.5000187755321673, 0.9955615889418641]]
# Covariance 3:  [[0.9755631955228826, 0.18260368252398734], [0.18260368252398734, 0.9704946928026956]]
# Weights:  {0: 0.20722337243634692, 1: 0.2982472464912047, 2: 0.4945293810724484}
# =============================================
# Iteration: 1
# Expectation done
# Maximization done
# Mean 1:  [3.0458770001690314, 3.0660454880789567]
# Mean 2:  [7.022852467107506, 4.0161596144740646]
# Mean 3:  [5.014746612080138, 7.004135855040982]
# Covariance 1:  [[1.0332759894946775, 0.0384639509978191], [0.0384639509978191, 3.42027360292296]]
# Covariance 2:  [[0.9882329520159965, 0.5001277145093495], [0.5001277145093495, 0.9955693808056224]]
# Covariance 3:  [[0.9760562862421457, 0.18290230811879662], [0.18290230811879662, 0.9709752703525045]]
# Weights:  {0: 0.2070284314858408, 1: 0.2982694080325583, 2: 0.49470216048160137}
# =============================================
# Iteration: 2
# Expectation done
# Maximization done
# Mean 1:  [3.0451337794311217, 3.06393339394988]
# Mean 2:  [7.022700434851902, 4.016077125723073]
# Mean 3:  [5.014384895832357, 7.003818655379679]
# Covariance 1:  [[1.032702423839107, 0.03705269569523795], [0.03705269569523795, 3.415973321782836]]
# Covariance 2:  [[0.9884889343925161, 0.5002246477152543], [0.5002246477152543, 0.995576857467612]]
# Covariance 3:  [[0.9764923298146785, 0.18316749244649363], [0.18316749244649363, 0.9714003592789636]]
# Weights:  {0: 0.2068564593971312, 1: 0.2982890762447208, 2: 0.49485446435814484}
# =============================================
# Iteration: 3
# Expectation done
# Maximization done
# Mean 1:  [3.0444786381316487, 3.0620720882521604]
# Mean 2:  [7.022565734215978, 4.016004088286804]
# Mean 3:  [5.014065705501308, 7.003538287948503]
# Covariance 1:  [[1.0321967955196714, 0.03581150676940157], [0.03581150676940157, 3.4121881678913852]]
# Covariance 2:  [[0.9887159049417223, 0.5003107589838083], [0.5003107589838083, 0.9955839161048576]]
# Covariance 3:  [[0.9768776091497137, 0.18340266196885788], [0.18340266196885788, 0.9717760506640573]]
# Weights:  {0: 0.2067048333579019, 1: 0.29830650816491955, 2: 0.49498865847717616}
# =============================================
# Iteration: 4
# Expectation done
# Maximization done
# Mean 1:  [3.04390140754444, 3.0604324906410763]
# Mean 2:  [7.022446521196947, 4.015939483347773]
# Mean 3:  [5.01378420564426, 7.003290669180442]
# Covariance 1:  [[1.031751273813858, 0.03472010750012615], [0.03472010750012615, 3.4088573894093552]]
# Covariance 2:  [[0.9889169126445411, 0.5003871482108195], [0.5003871482108195, 0.9955904975655346]]
# Covariance 3:  [[0.9772177860098694, 0.1836109657893538], [0.1836109657893538, 0.972107836525961]]
# Weights:  {0: 0.20657121108294496, 1: 0.29832194002085555, 2: 0.49510684889620243}
# =============================================
# Iteration: 5
# Expectation done
# Maximization done
# Mean 1:  [3.0433930305410053, 3.0589887345089304]
# Mean 2:  [7.022341116891599, 4.015882387278896]
# Mean 3:  [5.013536073443342, 7.003072124337352]
# Covariance 1:  [[1.0313588796722575, 0.033760586396012295], [0.033760586396012295, 3.405927180445503]]
# Covariance 2:  [[0.989094742141405, 0.500454828893084], [0.500454828893084, 0.9955965742610687]]
# Covariance 3:  [[0.9775179463487373, 0.1837952799499599], [0.1837952799499599, 0.9724006532659849]]
# Weights:  {0: 0.2064535051838131, 1: 0.2983355874198668, 2: 0.49521090739632173}
# =============================================
# Iteration: 6
# Expectation done
# Maximization done
# Mean 1:  [3.0429454547853525, 3.0577178480366114]
# Mean 2:  [7.022248000477774, 4.015831966207192]
# Mean 3:  [5.013317452905917, 7.002879356789986]
# Covariance 1:  [[1.0310134054075584, 0.032917134137661265], [0.032917134137661265, 3.4033499374855025]]
# Covariance 2:  [[0.9892519226952083, 0.5005147285252548], [0.5005147285252548, 0.9956021409946529]]
# Covariance 3:  [[0.9777826462182362, 0.18395821715895858], [0.18395821715895858, 0.9726589255893766]]
# Weights:  {0: 0.20634985882776713, 1: 0.2983476460351822, 2: 0.4953024951370502}
# =============================================
# Iteration: 7
# Expectation done
# Maximization done
# Mean 1:  [3.0425515325618835, 3.056599458388499]
# Mean 2:  [7.022165800220309, 4.015787469977992]
# Mean 3:  [5.013124911103797, 7.002709417057274]
# Covariance 1:  [[1.030709338801835, 0.03217580652891868], [0.03217580652891868, 3.4010835834914124]]
# Covariance 2:  [[0.9893907409851322, 0.5005676910273779], [0.5005676910273779, 0.9956072080560389]]
# Covariance 3:  [[0.9780159570476367, 0.18410214016752602], [0.18410214016752602, 0.9728866098274603]]
# Weights:  {0: 0.20625862290969557, 1: 0.2983582926140245, 2: 0.4953830844762796}
# =============================================
# Iteration: 8
# Expectation done
# Maximization done
# Mean 1:  [3.0422049278319276, 3.055615519538903]
# Mean 2:  [7.022093283339078, 4.015748225833486]
# Mean 3:  [5.0129553969286835, 7.002559672423336]
# Covariance 1:  [[1.0304417923199507, 0.03152431175217796], [0.03152431175217796, 3.3990909564728518]]
# Covariance 2:  [[0.9895132562588108, 0.5006144805538063], [0.5006144805538063, 0.9956117960616984]]
# Covariance 3:  [[0.9782215094179699, 0.18422917741438483], [0.18422917741438483, 0.9730872358589281]]
# Weights:  {0: 0.20617833485845855, 1: 0.29836768617908016, 2: 0.4954539789624633}
# =============================================
# Iteration: 9
# Expectation done
# Maximization done
# Mean 1:  [3.0419000307383115, 3.0547500634944513]
# Mean 2:  [7.022029345354117, 4.015713632042323]
# Mean 3:  [5.012806202643188, 7.002427777709927]
# Covariance 1:  [[1.0302064377537021, 0.030951820074445455], [0.030951820074445455, 3.3973392586348083]]
# Covariance 2:  [[0.9896213167441719, 0.5006557861828348], [0.5006557861828348, 0.9956159321350957]]
# Covariance 3:  [[0.9784025347236364, 0.18434123988903672], [0.18434123988903672, 0.973263947061189]]
# Weights:  {0: 0.20610769912265445, 1: 0.2983759693299663, 2: 0.4955163315473761}
# =============================================
# Iteration: 10
# Expectation done
# Maximization done
# Mean 1:  [3.0416318795123454, 3.0539889741623543]
# Mean 2:  [7.021972999347502, 4.015683151651351]
# Mean 3:  [5.012674928356109, 7.002311647589204]
# Covariance 1:  [[1.0299994463656497, 0.03044879410665773], [0.03044879410665773, 3.395799561820167]]
# Covariance 2:  [[0.9897165765157477, 0.500692227107391], [0.500692227107391, 0.9956196471115009]]
# Covariance 3:  [[0.9785619043281941, 0.1844400384325305], [0.1844400384325305, 0.9734195379160316]]
# Weights:  {0: 0.20604556932527954, 1: 0.298383269578071, 2: 0.4955711610966512}
# =============================================
# Iteration: 11
# Expectation done
# Maximization done
# Mean 1:  [3.0413960895534, 3.0533197827685394]
# Mean 2:  [7.021923365452513, 4.015656306480487]
# Mean 3:  [5.012559449441676, 7.0022094306719955]
# Covariance 1:  [[1.02981743442636, 0.030006837745914516], [0.030006837745914516, 3.394446364807212]]
# Covariance 2:  [[0.989800512239911, 0.500724358045032], [0.500724358045032, 0.995622973522796]]
# Covariance 3:  [[0.978702165991413, 0.18452710090937904], [0.18452710090937904, 0.9735564890491039]]
# Weights:  {0: 0.20599093203754482, 1: 0.29838970066810044, 2: 0.49561936729435413}
# =============================================
# Iteration: 12
# Expectation done
# Maximization done
# Mean 1:  [3.041188789332094, 3.052731483511903]
# Mean 2:  [7.021879660775919, 4.015632671437773]
# Mean 3:  [5.012457886840642, 7.002119485495207]
# Covariance 1:  [[1.0296574139226642, 0.02961856200380679], [0.02961856200380679, 3.3932571980298625]]
# Covariance 2:  [[0.989874439399259, 0.5007526746623078], [0.5007526746623078, 0.9956259441719527]]
# Covariance 3:  [[0.9788255774730561, 0.18460378885272055], [0.18460378885272055, 0.9736769996032744]]
# Weights:  {0: 0.20594289209580838, 1: 0.29839536385478793, 2: 0.49566174404940283}
# =============================================
# Iteration: 13
# Expectation done
# Maximization done
# Mean 1:  [3.0410065626932, 3.052214368020155]
# Mean 2:  [7.021841189887997, 4.01561186920503]
# Mean 3:  [5.012368580129036, 7.002040358445116]
# Covariance 1:  [[1.0295167481423406, 0.02927746602718545], [0.02927746602718545, 3.3922122714084706]]
# Covariance 2:  [[0.9899395277319255, 0.500777618869523], [0.500777618869523, 0.9956285911510172]]
# Covariance 3:  [[0.9789341373161985, 0.1846713133158269], [0.1846713133158269, 0.9737830169373928]]
# Weights:  {0: 0.2059006593689198, 1: 0.2984003491142703, 2: 0.49569899151680963}
# =============================================
# Iteration: 14
# Expectation done
# Maximization done
# Mean 1:  [3.040846397096481, 3.0517598771258974]
# Mean 2:  [7.021807335955111, 4.015593565316082]
# Mean 3:  [5.012290063202684, 7.00197076359658]
# Covariance 1:  [[1.029393111799702, 0.028977831735405645], [0.028977831735405645, 3.391294161179165]]
# Covariance 2:  [[0.9899968157219011, 0.5007995838878605], [0.5007995838878605, 0.9956309451894311]]
# Covariance 3:  [[0.9790296128807743, 0.1847307497627404], [0.1847307497627404, 0.9738762637091221]]
# Weights:  {0: 0.2058635368740314, 1: 0.298404736277937, 2: 0.49573172684803146}
# =============================================
# Iteration: 15
# Expectation done
# Maximization done
# Mean 1:  [3.040705637318115, 3.051360468485291]
# Mean 2:  [7.021777552551741, 4.015577463636053]
# Mean 3:  [5.012221042405019, 7.001909564401664]
# Covariance 1:  [[1.029284455348193, 0.028714630624613886], [0.028714630624613886, 3.39048753185353]]
# Covariance 2:  [[0.990047224052095, 0.5008189190267284], [0.5008189190267284, 0.9956330352463523]]
# Covariance 3:  [[0.9791135657466288, 0.18478305190569178], [0.18478305190569178, 0.973958262446549]]
# Weights:  {0: 0.20583091013516064, 1: 0.2984085960824815, 2: 0.49576049378235937}
# =============================================
# Iteration: 16
# Expectation done
# Maximization done
# Mean 1:  [3.0405819441384403, 3.051009498603647]
# Mean 2:  [7.0217513561579405, 4.015563302235832]
# Mean 3:  [5.0121603769157135, 7.001855757136939]
# Covariance 1:  [[1.0291889731236683, 0.028483441415316932], [0.028483441415316932, 3.389778889714355]]
# Covariance 2:  [[0.9900915679860771, 0.5008359341353106], [0.5008359341353106, 0.9956348882808987]]
# Covariance 3:  [[0.9791873746356156, 0.1848290644522273], [0.1848290644522273, 0.9740303577452524]]
# Weights:  {0: 0.20580223767878503, 1: 0.2984119911341284, 2: 0.49578577118708883}
# =============================================
# Iteration: 17
# Expectation done
# Maximization done
# Mean 1:  [3.0404732575573887, 3.0507011178981283]
# Mean 2:  [7.021728319328155, 4.01555084964736]
# Mean 3:  [5.012107061213731, 7.001808455997738]
# Covariance 1:  [[1.0291050749702915, 0.028280377343107087], [0.028280377343107087, 3.3891563645366283]]
# Covariance 2:  [[0.9901305686833608, 0.500850903711982], [0.500850903711982, 0.9956365291503504]]
# Covariance 3:  [[0.9792522560203469, 0.1848695347643802], [0.1848695347643802, 0.9740937362455789]]
# Weights:  {0: 0.20577704256361498, 1: 0.2984149767880213, 2: 0.49580798064836107}
# =============================================
# Iteration: 18
# Expectation done
# Maximization done
# Mean 1:  [3.0403777640999086, 3.050430177508849]
# Mean 2:  [7.0217080645040095, 4.015539901480627]
# Mean 3:  [5.012060209432607, 7.001766879722433]
# Covariance 1:  [[1.0290313610158819, 0.02810202200971935], [0.02810202200971935, 3.3886095165052335]]
# Covariance 2:  [[0.9901648634799435, 0.5008640706691966], [0.5008640706691966, 0.99563798059829]]
# Covariance 3:  [[0.9793092825961046, 0.18490512346014604], [0.18490512346014604, 0.9741494445549945]]
# Weights:  {0: 0.2057549048463366, 1: 0.29841760194573275, 2: 0.49582749320793257}
# =============================================
# Iteration: 19
# Expectation done
# Maximization done
# Mean 1:  [3.040293867802628, 3.0501921466609914]
# Mean 2:  [7.021690258435487, 4.015530277379121]
# Mean 3:  [5.0120190414325085, 7.00173033962303]
# Covariance 1:  [[1.0289665992837524, 0.027945372821622193], [0.027945372821622193, 3.3881291655781087]]
# Covariance 2:  [[0.9901950151835687, 0.5008756497613083], [0.5008756497613083, 0.9956392633047112]]
# Covariance 3:  [[0.9793593997931402, 0.18493641400578392], [0.18493641400578392, 0.97419840528233]]
# Weights:  {0: 0.20573545489084205, 1: 0.2984199097751518, 2: 0.4958446353340074}
# =============================================
# Iteration: 20
# Expectation done
# Maximization done
# Mean 1:  [3.040220164501843, 3.0499830394730916]
# Mean 2:  [7.021674607168247, 4.015521818288932]
# Mean 3:  [5.011982870421223, 7.00169822890023]
# Covariance 1:  [[1.0289097058495158, 0.02780779114534479], [0.02780779114534479, 3.38770724080592]]
# Covariance 2:  [[0.9902215204436889, 0.5008858306893039], [0.5008858306893039, 0.995640395976811]]
# Covariance 3:  [[0.9794034405034499, 0.1849639213589841], [0.1849639213589841, 0.9742414313487018]]
# Weights:  {0: 0.20571836743505587, 1: 0.29842193835777137, 2: 0.49585969420717163}
# =============================================
# Iteration: 21
# Expectation done
# Maximization done
# Mean 1:  [3.0401554190736864, 3.049799350201554]
# Mean 2:  [7.021660851553821, 4.015514384015823]
# Mean 3:  [5.0119510919700465, 7.001670013126378]
# Covariance 1:  [[1.0288597272749436, 0.02768695840197109], [0.02768695840197109, 3.3873366473668693]]
# Covariance 2:  [[0.9902448172624453, 0.5008947809007129], [0.5008947809007129, 0.995641395464979]]
# Covariance 3:  [[0.9794421381891742, 0.18498809972979746], [0.18498809972979746, 0.9742792387341049]]
# Weights:  {0: 0.2057033563359697, 1: 0.29842372126882594, 2: 0.49587292239520603}
# =============================================
# Iteration: 22
# Expectation done
# Maximization done
# Mean 1:  [3.0400985453079996, 3.049637996002411]
# Mean 2:  [7.021648763239794, 4.015507851045852]
# Mean 3:  [5.011923174279231, 7.001645221783801]
# Covariance 1:  [[1.0288158250733574, 0.02758083740857687], [0.02758083740857687, 3.3870111493054105]]
# Covariance 2:  [[0.9902652917153126, 0.5009026481055716], [0.5009026481055716, 0.9956422768929148]]
# Covariance 3:  [[0.9794761385302146, 0.1850093495283499], [0.1850093495283499, 0.974312457810215]]
# Weights:  {0: 0.2056901699204417, 1: 0.29842528809574936, 2: 0.49588454198381215}
# =============================================
# Iteration: 23
# Expectation done
# Maximization done
# Mean 1:  [3.0400485881269232, 3.049496266379301]
# Mean 2:  [7.021638141095527, 4.0155021106042215]
# Mean 3:  [5.011898649561027, 7.001623440752918]
# Covariance 1:  [[1.0287772619843556, 0.02748763835122363], [0.02748763835122363, 3.386725266174753]]
# Covariance 2:  [[0.9902832839492565, 0.5009095625298964], [0.5009095625298964, 0.9956430537937093]]
# Covariance 3:  [[0.9795060097585605, 0.18502802356879258], [0.18502802356879258, 0.9743416434004581]]
# Weights:  {0: 0.20567858687575302, 1: 0.2984266649004628, 2: 0.4958947482237846}
# =============================================
# Iteration: 24
# Expectation done
# Maximization done
# Mean 1:  [3.040004707886861, 3.0493717785677688]
# Mean 2:  [7.0216288080329194, 4.015497066930365]
# Mean 3:  [5.011877106419924, 7.001604305653199]
# Covariance 1:  [[1.0287433898561982, 0.027405788843587034], [0.027405788843587034, 3.386474181976638]]
# Covariance 2:  [[0.9902990935248298, 0.5009156389290484], [0.5009156389290484, 0.9956437382461591]]
# Covariance 3:  [[0.979532251815375, 0.18504443259698258], [0.18504443259698258, 0.9743672836982268]]
# Weights:  {0: 0.20566841262022553, 1: 0.2984278746307107, 2: 0.4959037127490628}
# =============================================
# Iteration: 25
# Expectation done
# Maximization done
# Mean 1:  [3.0399661665291196, 3.0492624381839972]
# Mean 2:  [7.021620608182819, 4.015492635746665]
# Mean 3:  [5.011858183120214, 7.001587495947465]
# Covariance 1:  [[1.0287136389550988, 0.02733390758730481], [0.02733390758730481, 3.386253664968218]]
# Covariance 2:  [[0.9903129841651153, 0.5009209783822274], [0.5009209783822274, 0.9956443410075386]]
# Covariance 3:  [[0.9795553044559173, 0.1850588502063212], [0.1850588502063212, 0.974389808163696]]
# Weights:  {0: 0.2056594761000847, 1: 0.29842893748546445, 2: 0.49591158641445315}
# =============================================
# Iteration: 26
# Expectation done
# Maximization done
# Mean 1:  [3.039932315368564, 3.0491664045352045]
# Mean 2:  [7.0216134043923315, 4.0154887429019155]
# Mean 3:  [5.0118415616423, 7.00157272972656]
# Covariance 1:  [[1.0286875085386735, 0.02727078120622289], [0.02727078120622289, 3.386059997063873]]
# Covariance 2:  [[0.9903251879709862, 0.5009256698889889], [0.5009256698889889, 0.9956448716404231]]
# Covariance 3:  [[0.9795755544160047, 0.18507151720234186], [0.18507151720234186, 0.9744095945085127]]
# Weights:  {0: 0.20565162696429656, 1: 0.2984298712389897, 2: 0.49591850179671226}
# =============================================
# Iteration: 27
# Expectation done
# Maximization done
# Mean 1:  [3.039902584331919, 3.049082060054198]
# Mean 2:  [7.021607076007067, 4.015485323169835]
# Mean 3:  [5.011826962438533, 7.001559759100601]
# Covariance 1:  [[1.0286645585485958, 0.027215343875864845], [0.027215343875864845, 3.3858899117030763]]
# Covariance 2:  [[0.9903359091568961, 0.5009297917869964], [0.5009297917869964, 0.9956453386317036]]
# Covariance 3:  [[0.9795933417432856, 0.18508264547241754], [0.18508264547241754, 0.974426974868671]]
# Weights:  {0: 0.20564473307412526, 1: 0.2984306915279296, 2: 0.49592457539794704}
# =============================================
# Iteration: 28
# Expectation done
# Maximization done
# Mean 1:  [3.0398764724781473, 3.049007983378894]
# Mean 2:  [7.021601516909666, 4.015482319186634]
# Mean 3:  [5.011814139809734, 7.001548366130156]
# Covariance 1:  [[1.0286444022926438, 0.027166659413956396], [0.027166659413956396, 3.3857405391842517]]
# Covariance 2:  [[0.990345327358526, 0.5009334130094815], [0.5009334130094815, 0.9956457495032108]]
# Covariance 3:  [[0.9796089653865939, 0.1850924214125712], [0.1850924214125712, 0.974442241255445]]
# Weights:  {0: 0.20563867830875715, 1: 0.29843141210531915, 2: 0.49592990958592137}
# =============================================
# Iteration: 29
# Expectation done
# Maximization done
# Mean 1:  [3.039853539650864, 3.0489429256510943]
# Mean 2:  [7.021596633786582, 4.015479680513115]
# Mean 3:  [5.011802877829533, 7.001538359234447]
# Covariance 1:  [[1.0286267000008131, 0.027123905537190445], [0.027123905537190445, 3.3856093585786713]]
# Covariance 2:  [[0.9903536005579665, 0.5009365941989302], [0.5009365941989302, 0.9956461109135605]]
# Covariance 3:  [[0.979622688126719, 0.1851010089586818], [0.1851010089586818, 0.9744556503651932]]
# Weights:  {0: 0.20563336063268078, 1: 0.2984320450651052, 2: 0.49593459430221054}
# =============================================
# Iteration: 30
# Expectation done
# Maximization done
# Mean 1:  [3.0398333991306776, 3.0488857896556225]
# Mean 2:  [7.0215923445964155, 4.015477362805062]
# Mean 3:  [5.01179298675496, 7.001529570025445]
# Covariance 1:  [[1.0286111531532598, 0.02708636002358353], [0.02708636002358353, 3.3854941554414]]
# Covariance 2:  [[0.990360867668232, 0.5009393886923675], [0.5009393886923675, 0.9956464287511019]]
# Covariance 3:  [[0.9796347409242313, 0.18510855226561296], [0.18510855226561296, 0.974467427821574]]
# Weights:  {0: 0.20562869039411466, 1: 0.2984326010404919, 2: 0.4959387085653944}
# =============================================
# Iteration: 31
# Expectation done
# Maximization done
# Mean 1:  [3.039815711169153, 3.0488356114652073]
# Mean 2:  [7.021588577219712, 4.015475327083038]
# Mean 3:  [5.011784299865042, 7.00152185051621]
# Covariance 1:  [[1.0285974994887443, 0.027053388551679186], [0.027053388551679186, 3.385392984626824]]
# Covariance 2:  [[0.9903672508154848, 0.5009418433924167], [0.5009418433924167, 0.9956467082184587]]
# Covariance 3:  [[0.9796453267508777, 0.18511517807287944], [0.18511517807287944, 0.9744777719144201]]
# Weights:  {0: 0.20562458882743118, 1: 0.29843308937893837, 2: 0.4959423217936272}
# =============================================
# Iteration: 32
# Expectation done
# Maximization done
# Mean 1:  [3.039800177300263, 3.0487915442935036]
# Mean 2:  [7.021585268266277, 4.015473539086813]
# Mean 3:  [5.011776670678457, 7.00151507066216]
# Covariance 1:  [[1.0285855086135107, 0.027024434013983814], [0.027024434013983814, 3.3853041375981583]]
# Covariance 2:  [[0.9903728573522028, 0.5009439995363755], [0.5009439995363755, 0.9956469539087104]]
# Covariance 3:  [[0.9796546239647306, 0.18512099779236596], [0.18512099779236596, 0.9744868568940565]]
# Weights:  {0: 0.20562098673543996, 1: 0.29843351829658404, 2: 0.4959454949679752}
# =============================================
# Iteration: 33
# Expectation done
# Maximization done
# Mean 1:  [3.0397865353370377, 3.0487528442943117]
# Mean 2:  [7.021582362025632, 4.015471968707933]
# Mean 3:  [5.011769970504489, 7.001509116195246]
# Covariance 1:  [[1.0285749781387779, 0.026999007127037927], [0.026999007127037927, 3.3852261136917625]]
# Covariance 2:  [[0.9903777816329508, 0.5009458933752521], [0.5009458933752521, 0.9956471698741962]]
# Covariance 3:  [[0.9796627892820854, 0.18512610934943866], [0.18512610934943866, 0.9744948358723995]]
# Weights:  {0: 0.20561782333021314, 1: 0.29843389501430423, 2: 0.49594828165548444}
# =============================================
# Iteration: 34
# Expectation done
# Maximization done
# Mean 1:  [3.0397745549716335, 3.0487188580741926]
# Mean 2:  [7.021579809541094, 4.015470589488649]
# Mean 3:  [5.011764086288792, 7.001503886717782]
# Covariance 1:  [[1.0285657302843407, 0.026976678181235874], [0.026976678181235874, 3.385157594861039]]
# Covariance 2:  [[0.9903821065788879, 0.5009475567724123], [0.5009475567724123, 0.9956473596879667]]
# Covariance 3:  [[0.979669960393514, 0.1851305988058582], [0.1851305988058582, 0.9745018433770517]]
# Weights:  {0: 0.20561504521360877, 1: 0.2984342258776505, 2: 0.49595072890873915}
# =============================================
# Iteration: 35
# Expectation done
# Maximization done
# Mean 1:  [3.03976403390678, 3.048689011713819]
# Mean 2:  [7.021577567794992, 4.0154693781815105]
# Mean 3:  [5.011758918718395, 7.001499294024429]
# Covariance 1:  [[1.0285576088921864, 0.026957069792689404], [0.026957069792689404, 3.3850974234805724]]
# Covariance 2:  [[0.9903859050564022, 0.5009490177314786], [0.5009490177314786, 0.995647526498938]]
# Covariance 3:  [[0.9796762582659357, 0.18513454178955602], [0.18513454178955602, 0.9745079975990679]]
# Weights:  {0: 0.20561260548083574, 1: 0.2984345164624553, 2: 0.4959528780567096}
# =============================================
# Iteration: 36
# Expectation done
# Maximization done
# Mean 1:  [3.0397547944548156, 3.0486628011170884]
# Mean 2:  [7.021575598990864, 4.015468314361164]
# Mean 3:  [5.011754380555295, 7.001495260626197]
# Covariance 1:  [[1.028550476801265, 0.026939850535620643], [0.026939850535620643, 3.385044582842012]]
# Covariance 2:  [[0.9903892410908579, 0.5009503008613696], [0.5009503008613696, 0.9956476730809767]]
# Covariance 3:  [[0.9796817891679777, 0.18513800475386732], [0.18513800475386732, 0.9745134023708072]]
# Weights:  {0: 0.20561046293231175, 1: 0.2984347716678177, 2: 0.49595476539986805}
# =============================================
# Iteration: 37
# Expectation done
# Maximization done
# Mean 1:  [3.03974668054863, 3.048639783528754]
# Mean 2:  [7.021573869922172, 4.0154673800829235]
# Mean 3:  [5.011750395171142, 7.001491718451885]
# Covariance 1:  [[1.028544213539931, 0.026924729348728773], [0.026924729348728773, 3.3849981800164812]]
# Covariance 2:  [[0.9903921709352688, 0.500951427785927], [0.500951427785927, 0.9956478018766095]]
# Covariance 3:  [[0.979686646451284, 0.18514104608606075], [0.18514104608606075, 0.9745181489055033]]
# Weights:  {0: 0.205608581380842, 1: 0.2984349957979493, 2: 0.4959564228212058}
# =============================================
# Iteration: 38
# Expectation done
# Maximization done
# Mean 1:  [3.039739555114201, 3.048619570079548]
# Mean 2:  [7.021572351416481, 4.015466559582413]
# Mean 3:  [5.01174689525934, 7.001488607706148]
# Covariance 1:  [[1.0285387132979043, 0.02691145062168248], [0.02691145062168248, 3.3849574307972423]]
# Covariance 2:  [[0.9903947440105272, 0.5009524175045088], [0.5009524175045088, 0.9956479150358817]]
# Covariance 3:  [[0.9796909121171121, 0.18514371708299443], [0.18514371708299443, 0.9745223173273801]]
# Weights:  {0: 0.20560692904269226, 1: 0.29843519263417945, 2: 0.4959578783231281}
# =============================================
# Iteration: 39
# Expectation done
# Maximization done
# Mean 1:  [3.039733297761987, 3.0486018192351776]
# Mean 2:  [7.021571017846974, 4.015465839011608]
# Mean 3:  [5.011743821702722, 7.001485875865415]
# Covariance 1:  [[1.0285338831440252, 0.02689978987907384], [0.02689978987907384, 3.3849216464716916]]
# Covariance 2:  [[0.9903970037328403, 0.5009532867094237], [0.5009532867094237, 0.9956480144508417]]
# Covariance 3:  [[0.9796946581936777, 0.1851460628094949], [0.1851460628094949, 0.9745259780169339]]
# Weights:  {0: 0.2056054780024185, 1: 0.29843536549829447, 2: 0.4959591564992842}
# =============================================
# Iteration: 40
# Expectation done
# Maximization done
# Mean 1:  [3.0397278027582564, 3.048586231040209]
# Mean 2:  [7.021569846702, 4.015465206205775]
# Mean 3:  [5.01174112257832, 7.001483476795035]
# Covariance 1:  [[1.028529641460295, 0.026889549989458646], [0.026889549989458646, 3.3848902222000063]]
# Covariance 2:  [[0.9903989882412783, 0.5009540500651131], [0.5009540500651131, 0.9956481017859914]]
# Covariance 3:  [[0.9796979479469015, 0.18514812285345691], [0.18514812285345691, 0.9745291927936768]]
# Weights:  {0: 0.2056042037425921, 1: 0.2984355173082678, 2: 0.49596027894913997}
# =============================================
# Iteration: 41
# Expectation done
# Maximization done
# Mean 1:  [3.039722977242267, 3.0485725420602727]
# Mean 2:  [7.021568818207816, 4.015464650479934]
# Mean 3:  [5.011738752283179, 7.001481369973745]
# Covariance 1:  [[1.0285259165657523, 0.02688055783567449], [0.02688055783567449, 3.384862626806778]]
# Covariance 2:  [[0.990400731037881, 0.5009547204539432], [0.5009547204539432, 0.9956481785054084]]
# Covariance 3:  [[0.9797008369449002, 0.18514993198993726], [0.18514993198993726, 0.9745320159558655]]
# Weights:  {0: 0.2056030847305794, 1: 0.29843565062722854, 2: 0.4959612646421934}
# =============================================
# Iteration: 42
# Expectation done
# Maximization done
# Mean 1:  [3.039718739660467, 3.0485605209390743]
# Mean 2:  [7.02156791499572, 4.0154641624487555]
# Mean 3:  [5.011736670765741, 7.001479519811183]
# Covariance 1:  [[1.0285226455076788, 0.026872661390275776], [0.026872661390275776, 3.3848383938136535]]
# Covariance 2:  [[0.9904022615502114, 0.500955309192144], [0.500955309192144, 0.995648245896556]]
# Covariance 3:  [[0.9797033739932011, 0.1851515207650085], [0.1851515207650085, 0.9745344951942259]]
# Weights:  {0: 0.20560210205547036, 1: 0.29843576770654606, 2: 0.4959621302379839}
# =============================================
# Iteration: 43
# Expectation done
# Maximization done
# Mean 1:  [3.0397150183905235, 3.0485499644947622]
# Mean 2:  [7.02156712181031, 4.015463733868976]
# Mean 3:  [5.011734842850629, 7.001477895048786]
# Covariance 1:  [[1.0285197729994389, 0.026865727147000442], [0.026865727147000442, 3.3848171135626326]]
# Covariance 2:  [[0.990403605626083, 0.5009558262198793], [0.5009558262198793, 0.9956483050914424]]
# Covariance 3:  [[0.9797056019568522, 0.18515291600913406], [0.18515291600913406, 0.9745366723950455]]
# Weights:  {0: 0.20560123910911637, 1: 0.2984358705236761, 2: 0.4959628903672059}
# =============================================
# Iteration: 44
# Expectation done
# Maximization done
# Mean 1:  [3.0397117505327804, 3.0485406942908084]
# Mean 2:  [7.021566425252475, 4.01546335750034]
# Mean 3:  [5.0117332376454256, 7.001476468232922]
# Covariance 1:  [[1.0285172504876305, 0.02685963786488633], [0.02685963786488633, 3.384798426297753]]
# Covariance 2:  [[0.9904047859682964, 0.500956280268222], [0.500956280268222, 0.9956483570851956]]
# Covariance 3:  [[0.9797075584827162, 0.1851541412884216], [0.1851541412884216, 0.9745385843458758]]
# Weights:  {0: 0.20560048130589667, 1: 0.29843596081545276, 2: 0.4959635578786486}
# =============================================
# Iteration: 45
# Expectation done
# Maximization done
# Mean 1:  [3.0397088808482624, 3.048532553623704]
# Mean 2:  [7.021565813554082, 4.015463026983987]
# Mean 3:  [5.011731828019733, 7.001475215252548]
# Covariance 1:  [[1.028515035332361, 0.026854290587046428], [0.026854290587046428, 3.384782016087994]]
# Covariance 2:  [[0.990405822516839, 0.5009566790060153], [0.5009566790060153, 0.9956484027525272]]
# Covariance 3:  [[0.9797092766341855, 0.18515521730123946], [0.18515521730123946, 0.9745402633556527]]
# Weights:  {0: 0.20559981583657036, 1: 0.2984360401073169, 2: 0.4959641440561142}
# =============================================
# Iteration: 46
# Expectation done
# Maximization done
# Mean 1:  [3.0397063608264103, 3.0485254048773958]
# Mean 2:  [7.021565276379417, 4.015462736735067]
# Mean 3:  [5.011730590147253, 7.001474114932366]
# Covariance 1:  [[1.0285130900874337, 0.026849594900622165], [0.026849594900622165, 3.384767605490403]]
# Covariance 2:  [[0.9904067327846631, 0.5009570291689073], [0.5009570291689073, 0.9956484428622017]]
# Covariance 3:  [[0.9797107854487481, 0.1851561622267306], [0.1851561622267306, 0.9745417377994224]]
# Weights:  {0: 0.20559923145202894, 1: 0.2984361097390268, 2: 0.49596465880894264}
# =============================================
# Iteration: 47
# Expectation done
# Maximization done
# Mean 1:  [3.039704147865618, 3.048519127199017]
# Mean 2:  [7.0215648046509935, 4.015462481848679]
# Mean 3:  [5.0117295031034255, 7.001473148675443]
# Covariance 1:  [[1.028511381867962, 0.0268454714087778], [0.0268454714087778, 3.384754950862389]]
# Covariance 2:  [[0.9904075321528151, 0.5009573366727516], [0.5009573366727516, 0.9956484780897641]]
# Covariance 3:  [[0.9797121104277942, 0.18515699203109637], [0.18515699203109637, 0.974543032596939]]
# Weights:  {0: 0.20559871827337947, 1: 0.298436170887234, 2: 0.49596511083938877}
# =============================================
# Iteration: 48
# Expectation done
# Maximization done
# Mean 1:  [3.0397022045539175, 3.048513614457755]
# Mean 2:  [7.0215643903967955, 4.015462258017238]
# Mean 3:  [5.011728548512488, 7.001472300149805]
# Covariance 1:  [[1.0285098817949738, 0.026841850388575544], [0.026841850388575544, 3.3847438382449058]]
# Covariance 2:  [[0.9904082341297498, 0.50095760671331], [0.50095760671331, 0.9956485090288866]]
# Covariance 3:  [[0.9797132739670741, 0.1851577207367726], [0.1851577207367726, 0.9745441696332705]]
# Weights:  {0: 0.2055982676250813, 1: 0.29843622458532554, 2: 0.49596550778959236}
# =============================================
# Iteration: 49
# Expectation done
# Maximization done
# Mean 1:  [3.0397004980368103, 3.04850877345193]
# Mean 2:  [7.021564026615216, 4.015462061457544]
# Mean 3:  [5.011727710236879, 7.001471555012553]
# Covariance 1:  [[1.0285085645075651, 0.026838670612503255], [0.026838670612503255, 3.3847340797467234]]
# Covariance 2:  [[0.9904088505790455, 0.5009578438537645], [0.5009578438537645, 0.9956485362011321]]
# Covariance 3:  [[0.9797142957346343, 0.1851583606588177], [0.1851583606588177, 0.9745451681280296]]
# Weights:  {0: 0.20559787188844325, 1: 0.29843627174085574, 2: 0.49596585637069956}
# =============================================
# Iteration: 50
# Expectation done
# Maximization done
# Mean 1:  [3.039698999462413, 3.048504522334317]
# Mean 2:  [7.021563707157758, 4.015461888847327]
# Mean 3:  [5.011726974104962, 7.001470900667564]
# Covariance 1:  [[1.0285074077344392, 0.02683587831342095], [0.02683587831342095, 3.384725510368882]]
# Covariance 2:  [[0.9904093919196947, 0.5009580521017498], [0.5009580521017498, 0.9956485600647854]]
# Covariance 3:  [[0.9797151930029059, 0.18515892261268663], [0.18515892261268663, 0.9745460449598774]]
# Weights:  {0: 0.2055975243728955, 1: 0.29843631315085667, 2: 0.4959661624762476}
# =============================================
# Iteration: 51
# Expectation done
# Maximization done
# Mean 1:  [3.0396976834937464, 3.0485007892292977]
# Mean 2:  [7.021563426624382, 4.0154617372687875]
# Mean 3:  [5.011726327671345, 7.001470326053261]
# Covariance 1:  [[1.0285063919176294, 0.026833426275591148], [0.026833426275591148, 3.3847179852161404]]
# Covariance 2:  [[0.9904098673017073, 0.5009582349768484], [0.5009582349768484, 0.9956485810224165]]
# Covariance 3:  [[0.9797159809404002, 0.18515941609670558], [0.18515941609670558, 0.9745468149516382]]
# Weights:  {0: 0.20559721920296778, 1: 0.2984363495152852, 2: 0.49596643128174783}
# =============================================
# Iteration: 52
# Expectation done
# Maximization done
# Mean 1:  [3.039696527880884, 3.048497511018165]
# Mean 2:  [7.021563180273018, 4.015461604159624]
# Mean 3:  [5.011725760007004, 7.001469821455391]
# Covariance 1:  [[1.0285054998819763, 0.02683127303652101], [0.02683127303652101, 3.384711377047736]]
# Covariance 2:  [[0.9904102847607851, 0.500958395570062], [0.500958395570062, 0.9956485994277088]]
# Covariance 3:  [[0.9797166728678399, 0.18515984945239364], [0.18515984945239364, 0.9745474911204373]]
# Weights:  {0: 0.20559695121899849, 1: 0.29843638144885015, 2: 0.49596666733215017}
# =============================================
# Iteration: 53
# Expectation done
# Maximization done
# Mean 1:  [3.0396955130845917, 3.048494632272434]
# Mean 2:  [7.021562963939015, 4.015461487269582]
# Mean 3:  [5.0117252615141235, 7.001469378343072]
# Covariance 1:  [[1.0285047165448873, 0.026829382185967865], [0.026829382185967865, 3.3847055741265817]]
# Covariance 2:  [[0.9904106513537718, 0.5009585365959072], [0.5009585365959072, 0.9956486155913175]]
# Covariance 3:  [[0.9797172804832165, 0.18516023000525855], [0.18516023000525855, 0.9745480848977085]]
# Weights:  {0: 0.2055967158899657, 1: 0.2984364094913822, 2: 0.49596687461865174}
# =============================================
# Iteration: 54
# Expectation done
# Maximization done
# Mean 1:  [3.0396946219463796, 3.0484921043170017]
# Mean 2:  [7.02156277396508, 4.015461384622565]
# Mean 3:  [5.011724823764524, 7.001468989224835]
# Covariance 1:  [[1.0285040286614189, 0.026827721750321616], [0.026827721750321616, 3.3847004783303754]]
# Covariance 2:  [[0.9904109732780089, 0.5009586604383032], [0.5009586604383032, 0.9956486297861601]]
# Covariance 3:  [[0.9797178140594317, 0.1851605641885412], [0.1851605641885412, 0.974548606322255]]
# Weights:  {0: 0.20559650923688227, 1: 0.29843643411695553, 2: 0.4959670566461631}
# =============================================
# Iteration: 55
# Expectation done
# Maximization done
# Mean 1:  [3.039693839398394, 3.048489884407615]
# Mean 2:  [7.021562607139712, 4.015461294483187]
# Mean 3:  [5.01172443935652, 7.001468647521634]
# Covariance 1:  [[1.028503424600416, 0.026826263652065464], [0.026826263652065464, 3.384696003492943]]
# Covariance 2:  [[0.9904112559759011, 0.5009587691907927], [0.5009587691907927, 0.9956486422519351]]
# Covariance 3:  [[0.9797182826178027, 0.18516085765179618], [0.18516085765179618, 0.974549064209853]]
# Weights:  {0: 0.20559632776556913, 1: 0.29843645574189254, 2: 0.4959672164925389}
# =============================================
# Iteration: 56
# Expectation done
# Maximization done
# Mean 1:  [3.0396931522086175, 3.048487935007973]
# Mean 2:  [7.021562460642263, 4.01546121532746]
# Mean 3:  [5.011724101790607, 7.00146834745618]
# Covariance 1:  [[1.0285028941479577, 0.026824983235033493], [0.026824983235033493, 3.3846920739472663]]
# Covariance 2:  [[0.9904115042267654, 0.5009588646918764], [0.5009588646918764, 0.9956486531991933]]
# Covariance 3:  [[0.9797186940805993, 0.1851611153563898], [0.1851611153563898, 0.9745494663022913]]
# Weights:  {0: 0.20559616840758926, 1: 0.29843647473179663, 2: 0.49596735686061466}
# =============================================
# Iteration: 57
# Expectation done
# Maximization done
# Mean 1:  [3.0396925487573907, 3.048486223155601]
# Mean 2:  [7.021562331995871, 4.015461145817075]
# Mean 3:  [5.011723805358952, 7.001468083954982]
# Covariance 1:  [[1.0285024283345858, 0.026823858847496825], [0.026823858847496825, 3.384688623246653]]
# Covariance 2:  [[0.9904117222277723, 0.5009589485561113], [0.5009589485561113, 0.9956486628128225]]
# Covariance 3:  [[0.979719055404835, 0.18516134165924342], [0.18516134165924342, 0.974549819398101]]
# Weights:  {0: 0.20559602846837388, 1: 0.29843649140773526, 2: 0.4959674801238931}
# =============================================
# Iteration: 58
# Expectation done
# Maximization done
# Mean 1:  [3.0396920188408365, 3.0484847199043594]
# Mean 2:  [7.021562219025508, 4.015461084776822]
# Mean 3:  [5.011723545049327, 7.001467852562674]
# Covariance 1:  [[1.0285020192837786, 0.02682287147612389], [0.02682287147612389, 3.3846855930409068]]
# Covariance 2:  [[0.990411913664754, 0.5009590222013647], [0.5009590222013647, 0.9956486712552844]]
# Covariance 3:  [[0.979719372699887, 0.18516154038650298], [0.18516154038650298, 0.9745501294674894]]
# Weights:  {0: 0.20559590558168012, 1: 0.2984365060516518, 2: 0.4959675883666652}
# =============================================
# Iteration: 59
# Expectation done
# Maximization done
# Mean 1:  [3.039691553498418, 3.0484833998352325]
# Mean 2:  [7.021562119820976, 4.015461031174569]
# Mean 3:  [5.011723316460055, 7.001467649366767]
# Covariance 1:  [[1.028501660078755, 0.026822004424439005], [0.026822004424439005, 3.384682932090115]]
# Covariance 2:  [[0.9904120817744134, 0.5009590868727529], [0.5009590868727529, 0.9956486786691847]]
# Covariance 3:  [[0.979719651330761, 0.18516171489815533], [0.18516171489815533, 0.9745504017532532]]
# Weights:  {0: 0.20559579766958871, 1: 0.2984365189111503, 2: 0.49596768341926034}
# =============================================
# Iteration: 60
# Expectation done
# Maximization done
# Mean 1:  [3.0396911448614365, 3.0484822406264707]
# Mean 2:  [7.021562032705058, 4.015460984104011]
# Mean 3:  [5.011723115725972, 7.001467470931506]
# Covariance 1:  [[1.0285013446455329, 0.026821243030553752], [0.026821243030553752, 3.3846805953979935]]
# Covariance 2:  [[0.990412229399203, 0.5009591436637233], [0.5009591436637233, 0.9956486851798352]]
# Covariance 3:  [[0.9797198960087756, 0.18516186814483834], [0.18516186814483834, 0.9745506408593974]]
# Weights:  {0: 0.20559570290737028, 1: 0.29843653020365896, 2: 0.495967766888972}
# =============================================
# Iteration: 61
# Expectation done
# Maximization done
# Mean 1:  [3.039690786020024, 3.048481222676331]
# Mean 2:  [7.021561956204727, 4.0154609427692645]
# Mean 3:  [5.0117229394527465, 7.001467314239688]
# Covariance 1:  [[1.0285010676502822, 0.026820574419211603], [0.026820574419211603, 3.3846785434513724]]
# Covariance 2:  [[0.990412359035165, 0.5009591935344847], [0.5009591935344847, 0.9956486908972536]]
# Covariance 3:  [[0.9797201108711845, 0.18516200271766875], [0.18516200271766875, 0.9745508508289444]]
# Weights:  {0: 0.2055956196926438, 1: 0.29843654012011345, 2: 0.49596784018724427}
# =============================================
# Iteration: 62
# Expectation done
# Maximization done
# Mean 1:  [3.039690470906228, 3.048480328771522]
# Mean 2:  [7.02156188902634, 4.015460906471386]
# Mean 3:  [5.011722784659736, 7.001467176641859]
# Covariance 1:  [[1.0285008244091005, 0.02681998728410098], [0.02681998728410098, 3.3846767415518064]]
# Covariance 2:  [[0.9904124728742503, 0.5009592373282516], [0.5009592373282516, 0.9956486959180512]]
# Covariance 3:  [[0.9797202995511524, 0.18516212089207476], [0.18516212089207476, 0.9745510352123126]]
# Weights:  {0: 0.20559554661828225, 1: 0.2984365488281897, 2: 0.4959679045535292}
# =============================================
# Iteration: 63
# Expectation done
# Maximization done
# Mean 1:  [3.0396901941916514, 3.0484795437963026]
# Mean 2:  [7.021561830034045, 4.0154608745966565]
# Mean 3:  [5.011722648729457, 7.001467055811264]
# Covariance 1:  [[1.0285006108088137, 0.02681947169665169], [0.02681947169665169, 3.3846751592292614]]
# Covariance 2:  [[0.9904125728413773, 0.5009592757855227], [0.5009592757855227, 0.9956487003271086]]
# Covariance 3:  [[0.9797204652391043, 0.18516222466622984], [0.18516222466622984, 0.9745511971272559]]
# Weights:  {0: 0.2055954824486113, 1: 0.29843655647513473, 2: 0.49596796107625735}
# =============================================
# Iteration: 64
# Expectation done
# Maximization done
# Mean 1:  [3.0396899511970332, 3.048478854476863]
# Mean 2:  [7.021561778230404, 4.015460846606079]
# Mean 3:  [5.0117225293633645, 7.0014669497048265]
# Covariance 1:  [[1.0285004232374924, 0.02681901893817869], [0.02681901893817869, 3.3846737697265517]]
# Covariance 2:  [[0.9904126606268752, 0.5009593095565502], [0.5009593095565502, 0.9956487041989597]]
# Covariance 3:  [[0.9797206107367491, 0.18516231579485162], [0.18516231579485162, 0.9745513393116926]]
# Weights:  {0: 0.2055954260985394, 1: 0.2984365631902477, 2: 0.4959680107112124}
# =============================================
# Iteration: 65
# Expectation done
# Maximization done
# Mean 1:  [3.0396897378133287, 3.0484782491568314]
# Mean 2:  [7.02156173273939, 4.015460822026325]
# Mean 3:  [5.011722424542967, 7.001466856528244]
# Covariance 1:  [[1.0285002585233245, 0.026818621352445355], [0.026818621352445355, 3.3846725495470023]]
# Covariance 2:  [[0.9904127377150931, 0.5009593392123625], [0.5009593392123625, 0.9956487075990264]]
# Covariance 3:  [[0.9797207385043898, 0.1851623958188318], [0.1851623958188318, 0.9745514641698572]]
# Weights:  {0: 0.20559537661519553, 1: 0.29843656908707744, 2: 0.49596805429772584}
# =============================================
# Iteration: 66
# Expectation done
# Maximization done
# Mean 1:  [3.039689550432252, 3.0484777176002456]
# Mean 2:  [7.021561692791807, 4.015460800441879]
# Mean 3:  [5.011722332495803, 7.001466774705955]
# Covariance 1:  [[1.0285001138809773, 0.026818272216160875], [0.026818272216160875, 3.3846714780571134]]
# Covariance 2:  [[0.990412805409578, 0.5009593652544303], [0.5009593652544303, 0.9956487105848164]]
# Covariance 3:  [[0.9797208507025291, 0.18516246609132736], [0.18516246609132736, 0.9745515738130833]]
# Weights:  {0: 0.2055953331618165, 1: 0.2984365742653328, 2: 0.49596809257284996}
# =============================================
# Iteration: 67
# Expectation done
# Maximization done
# Mean 1:  [3.0396893858852225, 3.0484772508184452]
# Mean 2:  [7.021561657712094, 4.015460781487595]
# Mean 3:  [5.01172225166538, 7.001466702854373]
# Covariance 1:  [[1.0284999868645672, 0.02681796562532144], [0.02681796562532144, 3.3846705371379153]]
# Covariance 2:  [[0.9904128648549737, 0.5009593881230677], [0.5009593881230677, 0.9956487132067919]]
# Covariance 3:  [[0.9797209492284207, 0.18516252780060644], [0.18516252780060644, 0.9745516700954092]]
# Weights:  {0: 0.20559529500360268, 1: 0.29843657881258184, 2: 0.4959681261838129}
# =============================================
# Iteration: 68
# Expectation done
# Maximization done
# Mean 1:  [3.03968924138967, 3.0484768409181404]
# Mean 2:  [7.021561626907218, 4.015460764843068]
# Mean 3:  [5.011722180684758, 7.0014666397584655]
# Covariance 1:  [[1.0284998753262176, 0.02681769639540814], [0.02681769639540814, 3.384669710878212]]
# Covariance 2:  [[0.9904129170565048, 0.500959408205007], [0.500959408205007, 0.9956487155092701]]
# Covariance 3:  [[0.9797210357481063, 0.1851625819901388], [0.1851625819901388, 0.9745517546449236]]
# Weights:  {0: 0.20559526149530083, 1: 0.2984365828057116, 2: 0.4959681556989866}
# =============================================
# Iteration: 69
# Expectation done
# Maximization done
# Mean 1:  [3.0396891145021727, 3.0484764809677674]
# Mean 2:  [7.021561599856066, 4.015460750226788]
# Mean 3:  [5.0117221183538145, 7.001466584351307]
# Covariance 1:  [[1.028499777379817, 0.026817459973644757], [0.026817459973644757, 3.3846689853056864]]
# Covariance 2:  [[0.9904129628968427, 0.5009594258398038], [0.5009594258398038, 0.9956487175311953]]
# Covariance 3:  [[0.9797211117246541, 0.18516262957625937], [0.18516262957625937, 0.9745518288913936]]
# Weights:  {0: 0.20559523207027997, 1: 0.29843658631224673, 2: 0.4959681816174735}
# =============================================
# Iteration: 70
# Expectation done
# Maximization done
# Mean 1:  [3.0396890030770494, 3.0484761648805923]
# Mean 2:  [7.021561576101367, 4.015460737391661]
# Mean 3:  [5.01172206361838, 7.0014665356960055]
# Covariance 1:  [[1.0284996913690418, 0.026817252362048825], [0.026817252362048825, 3.3846683481508477]]
# Covariance 2:  [[0.9904130031511813, 0.5009594413256684], [0.5009594413256684, 0.995648719306738]]
# Covariance 3:  [[0.9797211784428118, 0.18516267136362444], [0.18516267136362444, 0.9745518940903061]]
# Weights:  {0: 0.20559520623095703, 1: 0.298436589391481, 2: 0.4959682043775624}
# =============================================
# Iteration: 71
# Expectation done
# Maximization done
# Mean 1:  [3.039688905230078, 3.048475887311453]
# Mean 2:  [7.021561555241355, 4.0154607261205815]
# Mean 3:  [5.011722015553027, 7.001466492969762]
# Covariance 1:  [[1.0284996158394593, 0.02681707004985511], [0.02681707004985511, 3.3846677886391254]]
# Covariance 2:  [[0.9904130385001919, 0.5009594549244508], [0.5009594549244508, 0.9956487208659293]]
# Covariance 3:  [[0.9797212370307872, 0.18516270805886323], [0.18516270805886323, 0.9745519513441719]]
# Weights:  {0: 0.20559518354038633, 1: 0.2984365920954861, 2: 0.49596822436412713}
# =============================================
# Iteration: 72
# Expectation done
# Maximization done
# Mean 1:  [3.0396888193066567, 3.0484756435666602]
# Mean 2:  [7.021561536923348, 4.01546071622296]
# Mean 3:  [5.011721973344791, 7.001466455450103]
# Covariance 1:  [[1.0284995495138345, 0.026816909954091167], [0.026816909954091167, 3.3846672973090906]]
# Covariance 2:  [[0.990413069541631, 0.500959466866115], [0.500959466866115, 0.9956487222351224]]
# Covariance 3:  [[0.9797212884793034, 0.1851627402824726], [0.1851627402824726, 0.9745520016211496]]
# Weights:  {0: 0.2055951636148675, 1: 0.2984365944699837, 2: 0.49596824191514755}
# =============================================
# Iteration: 73
# Expectation done
# Maximization done
# Mean 1:  [3.0396887438537608, 3.0484754295243706]
# Mean 2:  [7.021561520837483, 4.015460707531461]
# Mean 3:  [5.011721936280056, 7.0014664225025856]
# Covariance 1:  [[1.0284994912705945, 0.026816769367503716], [0.026816769367503716, 3.3846668658521115]]
# Covariance 2:  [[0.9904130968003998, 0.5009594773525838], [0.5009594773525838, 0.9956487234374722]]
# Covariance 3:  [[0.9797213336583603, 0.18516276857936373], [0.18516276857936373, 0.97455204577144]]
# Weights:  {0: 0.20559514611745425, 1: 0.2984365965551292, 2: 0.49596825732741534}
# =============================================
# Iteration: 74
# Expectation done
# Maximization done
# Mean 1:  [3.039688677595508, 3.048475241565125]
# Mean 2:  [7.021561506711827, 4.015460699899087]
# Mean 3:  [5.011721903731939, 7.0014663935699275]
# Covariance 1:  [[1.0284994401248235, 0.026816645912702202], [0.026816645912702202, 3.3846664869722156]]
# Covariance 2:  [[0.9904131207374635, 0.500959486561192], [0.500959486561192, 0.995648724493311]]
# Covariance 3:  [[0.979721373331949, 0.1851627934280316], [0.1851627934280316, 0.9745520845416052]]
# Weights:  {0: 0.20559513075225905, 1: 0.2984365983861836, 2: 0.4959682708615569}
# =============================================
# Iteration: 75
# Expectation done
# Maximization done
# Mean 1:  [3.039688619411412, 3.048475076510422]
# Mean 2:  [7.021561494307628, 4.015460693196831]
# Mean 3:  [5.011721875150132, 7.001466368163029]
# Covariance 1:  [[1.0284993952116275, 0.026816537502023136], [0.026816537502023136, 3.3846661542623266]]
# Covariance 2:  [[0.9904131417575982, 0.500959494647657], [0.500959494647657, 0.9956487254205015]]
# Covariance 3:  [[0.9797214081709553, 0.1851628152486811], [0.1851628152486811, 0.9745521185872934]]
# Weights:  {0: 0.20559511725945245, 1: 0.29843659999410477, 2: 0.49596828274644106}
# =============================================
# Iteration: 76
# Expectation done
# Maximization done
# Mean 1:  [3.039688568317613, 3.048474931569138]
# Mean 2:  [7.021561483414862, 4.01546068731124]
# Mean 3:  [5.011721850051277, 7.001466345852164]
# Covariance 1:  [[1.0284993557715272, 0.026816442302195456], [0.026816442302195456, 3.384665862096197]]
# Covariance 2:  [[0.990413160216208, 0.5009595017487013], [0.5009595017487013, 0.9956487262346908]]
# Covariance 3:  [[0.979721438764508, 0.18516283441028816], [0.18516283441028816, 0.974552148484213]]
# Weights:  {0: 0.2055951054108709, 1: 0.2984366014060887, 2: 0.49596829318304064}
# =============================================
