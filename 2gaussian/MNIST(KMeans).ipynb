# %%
from tensorflow.examples.tutorials.mnist import input_data
from scipy.spatial import distance
import numpy as np
from datetime import datetime
import math
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
mnist = input_data.read_data_sets("MNIST_data/")

training_images = mnist.train.images
training_labels = mnist.train.labels
test_images = mnist.test.images
test_labels = mnist.test.labels
images = np.concatenate((training_images, test_images), axis = 0)
labels = np.concatenate((training_labels, test_labels), axis = 0)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def get_distance(a,b):
    return distance.euclidean(a,b)

# %%
def make_clusters(images, centroids, k):
    number_of_images = images.shape[0]
    clusters = [[] for i in range(0, k)]

    for i in range(0, number_of_images - 1):
        distances = []
        for j in range(0, k):
            distance = get_distance(images[i], centroids[j])
            distances.append((distance, j))

        distances = sorted(distances)
        cluster_number = distances[0][1]
        clusters[cluster_number].append(i)


    return clusters

# %%
def recalculate_centroids(centroids, clusters):
    for i in range (0, len(clusters)):
        image_list = []
        for image_index in clusters[i]:
            image_list.append(images[image_index])
        np_array = np.array(image_list)
        centroids[i] = np_array.mean(axis = 0)

    return centroids

# %%
def remake_cluster(clusters, centroids):
    total_images_reclustered = 0
    for i in range(0, len(clusters)):
        cluster = clusters[i]
        number_of_images_reclustered = 0
        for image_index in cluster:
            distances_to_each_centroid = {}
            for j in range(0 , len(centroids)):
                distance = get_distance(images[image_index], centroids[j])
                distances_to_each_centroid[j] = distance

            min_distance = distances_to_each_centroid[0]
            min_distance_index = 0
            for cluster_no in distances_to_each_centroid.keys():
                if distances_to_each_centroid[cluster_no] < min_distance:
                    min_distance = distances_to_each_centroid[cluster_no]
                    min_distance_index = cluster_no
            if min_distance_index != i:
                clusters[i].remove(image_index)
                clusters[min_distance_index].append(image_index)
                change_occured = True
                number_of_images_reclustered += 1
        total_images_reclustered += number_of_images_reclustered
    return clusters, total_images_reclustered

# %%
def calculate_purity_of_clusters(clusters):
    total_purity = 0
    for i in range(0, len(clusters)):
        majority = majority_count_of_cluster(clusters[i])
        total_purity += majority
    total_purity = total_purity / len(images)
    return total_purity

# %%
def majority_count_of_cluster(cluster):
    label_occurance = {}
    for image_index in cluster:
        label = labels[image_index]
        if label in label_occurance:
            label_occurance[label] += 1
        else:
            label_occurance[label] = 1
    majority_label = ""
    max_occurance = 0
    for label in label_occurance.keys():
        if label_occurance[label] > max_occurance:
            max_occurance = label_occurance[label]
            majority_label = label
    
    majority_count = 0
    for image_index in cluster:
        if labels[image_index] == majority_label:
            majority_count += 1
    
    return majority_count

# %%
def calculate_gini_index(clusters):
    gini_total = 0
    for cluster in clusters:
        cluster_gini = 1
        image_index_count = create_image_index_count_dict(cluster)
        for label in image_index_count.keys():
            cluster_gini = cluster_gini - math.pow((image_index_count[label] / len(cluster)) , 2)
        gini_total += cluster_gini * len(cluster)
    
    return gini_total / len(images)

# %%
def create_image_index_count_dict(cluster):
    image_index_count = {}
    for image_index in cluster:
        label = labels[image_index]
        if label in image_index_count:
            image_index_count[label] += 1
        else:
            image_index_count[label] = 1
    return image_index_count

# %%
def create_image_index_count_dict(cluster):
    image_index_count = {}
    for image_index in cluster:
        label = labels[image_index]
        if label in image_index_count:
            image_index_count[label] += 1
        else:
            image_index_count[label] = 1
    return image_index_count

# %%
def KMeans(k):

    number_of_images = images.shape[0]

    startTime = datetime.now()
    centroid_indexs = np.linspace(0, number_of_images-1, k)
    centroid_indexs = list(map(int, centroid_indexs))
    
    centroids = []
    for i in range(0, len(centroid_indexs)):
        centroids.append(images[centroid_indexs[i]])
    # initial clusters
    clusters = make_clusters(images, centroids, k)

    iterate = True
    while(iterate):
        centroids = recalculate_centroids(centroids, clusters)
        clusters, total_images_reclustered = remake_cluster(clusters, centroids)
        purity_of_clusters = calculate_purity_of_clusters(clusters)
        gini_index = calculate_gini_index(clusters)
        print("Purity of cluster: " + str(purity_of_clusters))
        print("Gini index: " + str(gini_index))
        print("Total images reclustered: " + str(total_images_reclustered))
        print()
        
        if total_images_reclustered == 0:
            iterate = False
            
    return clusters

# %%
print("Starting KMeans.....\n")
clusters = KMeans(10)
print("Done")
# Out:
# Starting KMeans.....
#
# Purity of cluster: 0.42049230769230767
# Gini index: 0.7048758125773793
# Total images reclustered: 15154
#
# Purity of cluster: 0.44464615384615386
# Gini index: 0.6793639049781723
# Total images reclustered: 10404
#
# Purity of cluster: 0.45863076923076923
# Gini index: 0.6598276065128407
# Total images reclustered: 7305
#
# Purity of cluster: 0.4813846153846154
# Gini index: 0.6411267050501133
# Total images reclustered: 5572
#
# Purity of cluster: 0.5026461538461539
# Gini index: 0.6238797507945099
# Total images reclustered: 4557
#
# Purity of cluster: 0.5236615384615385
# Gini index: 0.6062330305247313
# Total images reclustered: 3724
#
# Purity of cluster: 0.5414307692307693
# Gini index: 0.5888666592183857
# Total images reclustered: 3156
#
# Purity of cluster: 0.5553076923076923
# Gini index: 0.5735991172851713
# Total images reclustered: 2593
#
# Purity of cluster: 0.5659846153846154
# Gini index: 0.5613075013726744
# Total images reclustered: 2120
#
# Purity of cluster: 0.5738
# Gini index: 0.553291043032778
# Total images reclustered: 1697
#
# Purity of cluster: 0.5802307692307692
# Gini index: 0.5466598930202851
# Total images reclustered: 1368
#
# Purity of cluster: 0.5848615384615384
# Gini index: 0.5422520549569946
# Total images reclustered: 1191
#
# Purity of cluster: 0.589
# Gini index: 0.5381964521283242
# Total images reclustered: 1061
#
# Purity of cluster: 0.5926615384615385
# Gini index: 0.5345444776942642
# Total images reclustered: 940
#
# Purity of cluster: 0.5952153846153846
# Gini index: 0.5318342272238664
# Total images reclustered: 817
#
# Purity of cluster: 0.5974
# Gini index: 0.5303052591669862
# Total images reclustered: 752
#
# Purity of cluster: 0.5991846153846154
# Gini index: 0.5294147601685878
# Total images reclustered: 689
#
# Purity of cluster: 0.6007076923076923
# Gini index: 0.529011233485295
# Total images reclustered: 594
#
# Purity of cluster: 0.6021230769230769
# Gini index: 0.5285470348217646
# Total images reclustered: 513
#
# Purity of cluster: 0.6023846153846154
# Gini index: 0.5289599496027557
# Total images reclustered: 465
#
# Purity of cluster: 0.6022461538461539
# Gini index: 0.53003971668673
# Total images reclustered: 421
#
# Purity of cluster: 0.6016615384615385
# Gini index: 0.5311078686377791
# Total images reclustered: 405
#
# Purity of cluster: 0.6009538461538462
# Gini index: 0.5323695277699284
# Total images reclustered: 416
#
# Purity of cluster: 0.5994
# Gini index: 0.5340373949701325
# Total images reclustered: 438
#
# Purity of cluster: 0.5979538461538462
# Gini index: 0.5353870266356672
# Total images reclustered: 477
#
# Purity of cluster: 0.5959538461538462
# Gini index: 0.5369597575416065
# Total images reclustered: 472
#
# Purity of cluster: 0.5939384615384615
# Gini index: 0.5383659182387229
# Total images reclustered: 441
#
# Purity of cluster: 0.5926461538461538
# Gini index: 0.539598439689577
# Total images reclustered: 447
#
# Purity of cluster: 0.5918461538461538
# Gini index: 0.54074824921156
# Total images reclustered: 436
#
# Purity of cluster: 0.5909076923076924
# Gini index: 0.5418426009319818
# Total images reclustered: 388
#
# Purity of cluster: 0.5903538461538461
# Gini index: 0.5424930643659969
# Total images reclustered: 336
#
# Purity of cluster: 0.5899230769230769
# Gini index: 0.5429317338675059
# Total images reclustered: 291
#
# Purity of cluster: 0.5894615384615385
# Gini index: 0.5433485473041906
# Total images reclustered: 257
#
# Purity of cluster: 0.5890461538461539
# Gini index: 0.5437288402165861
# Total images reclustered: 234
#
# Purity of cluster: 0.5884
# Gini index: 0.5441780303655132
# Total images reclustered: 215
#
# Purity of cluster: 0.5882923076923077
# Gini index: 0.54429840342793
# Total images reclustered: 180
#
# Purity of cluster: 0.5878307692307693
# Gini index: 0.5445212852279877
# Total images reclustered: 184
#
# Purity of cluster: 0.5876615384615385
# Gini index: 0.5446504114330969
# Total images reclustered: 186
#
# Purity of cluster: 0.5874923076923076
# Gini index: 0.5447677389694036
# Total images reclustered: 156
#
# Purity of cluster: 0.5873384615384616
# Gini index: 0.54486827257136
# Total images reclustered: 133
#
# Purity of cluster: 0.5871076923076923
# Gini index: 0.5450521668433482
# Total images reclustered: 134
#
# Purity of cluster: 0.5870153846153846
# Gini index: 0.5451195826667313
# Total images reclustered: 115
#
# Purity of cluster: 0.5867384615384615
# Gini index: 0.5453573510038421
# Total images reclustered: 113
#
# Purity of cluster: 0.5866615384615385
# Gini index: 0.5454281726634379
# Total images reclustered: 124
#
# Purity of cluster: 0.5865384615384616
# Gini index: 0.5455760569139033
# Total images reclustered: 114
#
# Purity of cluster: 0.5862461538461539
# Gini index: 0.5458077909523193
# Total images reclustered: 103
#
# Purity of cluster: 0.5860307692307692
# Gini index: 0.5460243031149474
# Total images reclustered: 119
#
# Purity of cluster: 0.5859846153846154
# Gini index: 0.546087109152759
# Total images reclustered: 117
#
# Purity of cluster: 0.5860153846153846
# Gini index: 0.5461137867639222
# Total images reclustered: 124
#
# Purity of cluster: 0.5859230769230769
# Gini index: 0.5462376546073845
# Total images reclustered: 130
#
# Purity of cluster: 0.5860461538461539
# Gini index: 0.5461290288556824
# Total images reclustered: 134
#
# Purity of cluster: 0.5859076923076924
# Gini index: 0.5462393334722987
# Total images reclustered: 146
#
# Purity of cluster: 0.5859076923076924
# Gini index: 0.5462532333434578
# Total images reclustered: 129
#
# Purity of cluster: 0.5856769230769231
# Gini index: 0.5463641673726217
# Total images reclustered: 139
#
# Purity of cluster: 0.5856153846153846
# Gini index: 0.546466732847554
# Total images reclustered: 147
#
# Purity of cluster: 0.5856461538461538
# Gini index: 0.5464567133766155
# Total images reclustered: 130
#
# Purity of cluster: 0.5853538461538461
# Gini index: 0.5466712861993706
# Total images reclustered: 129
#
# Purity of cluster: 0.585323076923077
# Gini index: 0.5466303310953579
# Total images reclustered: 112
#
# Purity of cluster: 0.5852461538461539
# Gini index: 0.5465715064810576
# Total images reclustered: 104
#
# Purity of cluster: 0.5851692307692308
# Gini index: 0.5465263795096864
# Total images reclustered: 82
#
# Purity of cluster: 0.585
# Gini index: 0.5466051889547907
# Total images reclustered: 93
#
# Purity of cluster: 0.5848769230769231
# Gini index: 0.5466193165406329
# Total images reclustered: 108
#
# Purity of cluster: 0.5848461538461538
# Gini index: 0.5466548711892831
# Total images reclustered: 106
#
# Purity of cluster: 0.5846307692307692
# Gini index: 0.5468213532378429
# Total images reclustered: 102
#
# Purity of cluster: 0.5845230769230769
# Gini index: 0.5468938781462898
# Total images reclustered: 102
#
# Purity of cluster: 0.5845230769230769
# Gini index: 0.5469108726326087
# Total images reclustered: 103
#
# Purity of cluster: 0.5843384615384616
# Gini index: 0.5470658759322271
# Total images reclustered: 90
#
# Purity of cluster: 0.5841692307692308
# Gini index: 0.5472371221186234
# Total images reclustered: 86
#
# Purity of cluster: 0.5840615384615384
# Gini index: 0.5473313876220578
# Total images reclustered: 73
#
# Purity of cluster: 0.5840153846153846
# Gini index: 0.5473469330521304
# Total images reclustered: 60
#
# Purity of cluster: 0.5839230769230769
# Gini index: 0.547384014758194
# Total images reclustered: 55
#
# Purity of cluster: 0.5838615384615384
# Gini index: 0.5474991089191114
# Total images reclustered: 61
#
# Purity of cluster: 0.5838923076923077
# Gini index: 0.54759245987793
# Total images reclustered: 47
#
# Purity of cluster: 0.5838615384615384
# Gini index: 0.5476498729827914
# Total images reclustered: 52
#
# Purity of cluster: 0.5839384615384615
# Gini index: 0.5476553809763642
# Total images reclustered: 43
#
# Purity of cluster: 0.5840307692307692
# Gini index: 0.5476927211890399
# Total images reclustered: 41
#
# Purity of cluster: 0.5841076923076923
# Gini index: 0.5477117803800046
# Total images reclustered: 50
#
# Purity of cluster: 0.5841384615384615
# Gini index: 0.5478037938320297
# Total images reclustered: 73
#
# Purity of cluster: 0.5841692307692308
# Gini index: 0.5477828072011439
# Total images reclustered: 74
#
# Purity of cluster: 0.5842923076923077
# Gini index: 0.5476656884594713
# Total images reclustered: 66
#
# Purity of cluster: 0.5843076923076923
# Gini index: 0.547582108701542
# Total images reclustered: 58
#
# Purity of cluster: 0.5844153846153847
# Gini index: 0.5475135813828726
# Total images reclustered: 52
#
# Purity of cluster: 0.5843384615384616
# Gini index: 0.5475587363197615
# Total images reclustered: 35
# Purity of cluster: 0.5841538461538461
# Gini index: 0.5476092652006648
# Total images reclustered: 30
#
# Purity of cluster: 0.5841076923076923
# Gini index: 0.5476428281710426
# Total images reclustered: 22
#
# Purity of cluster: 0.5840923076923077
# Gini index: 0.5475787970515861
# Total images reclustered: 23
#
# Purity of cluster: 0.5840461538461539
# Gini index: 0.547567079284058
# Total images reclustered: 19
#
# Purity of cluster: 0.584076923076923
# Gini index: 0.5475268630307947
# Total images reclustered: 16
#
# Purity of cluster: 0.5840923076923077
# Gini index: 0.5475248723208603
# Total images reclustered: 17
#
# Purity of cluster: 0.584076923076923
# Gini index: 0.547534735636107
# Total images reclustered: 23
#
# Purity of cluster: 0.5840461538461539
# Gini index: 0.5475918221997137
# Total images reclustered: 15
#
# Purity of cluster: 0.5839692307692308
# Gini index: 0.5476522615460556
# Total images reclustered: 11
#
# Purity of cluster: 0.5839384615384615
# Gini index: 0.5476642186732004
# Total images reclustered: 10
#
# Purity of cluster: 0.5839692307692308
# Gini index: 0.5476438975488823
# Total images reclustered: 6
#
# Purity of cluster: 0.5839384615384615
# Gini index: 0.5476648802258193
# Total images reclustered: 5
#
# Purity of cluster: 0.5839384615384615
# Gini index: 0.5476530307848287
# Total images reclustered: 2
#
# Purity of cluster: 0.5839230769230769
# Gini index: 0.5476653693937599
# Total images reclustered: 2
#
# Purity of cluster: 0.5839384615384615
# Gini index: 0.5476378867670888
# Total images reclustered: 2
#
# Purity of cluster: 0.5839538461538462
# Gini index: 0.5476362931038792
# Total images reclustered: 1
#
# Purity of cluster: 0.5839538461538462
# Gini index: 0.5476362931038792
# Total images reclustered: 0
#
# Purity of cluster: 0.5839538461538462
# Gini index: 0.5476362931038792
# Total images reclustered: 0
#
# Done

# %%
print("Starting KMeans.....\n")
clusters = KMeans(5)
print("Done")
# Out:
# Starting KMeans.....
#
# Purity of cluster: 0.30146153846153845
# Gini index: 0.8029003395629009
# Total images reclustered: 11649
#
# Purity of cluster: 0.3258923076923077
# Gini index: 0.7851957525224695
# Total images reclustered: 7407
#
# Purity of cluster: 0.33966153846153846
# Gini index: 0.7717841486280311
# Total images reclustered: 4960
#
# Purity of cluster: 0.34747692307692307
# Gini index: 0.7617970877701108
# Total images reclustered: 3459
#
# Purity of cluster: 0.35655384615384617
# Gini index: 0.7549193582389453
# Total images reclustered: 2274
#
# Purity of cluster: 0.3629538461538461
# Gini index: 0.750440082522088
# Total images reclustered: 1540
#
# Purity of cluster: 0.3670307692307692
# Gini index: 0.7476347382286057
# Total images reclustered: 1048
#
# Purity of cluster: 0.3698
# Gini index: 0.7459196333830733
# Total images reclustered: 759
#
# Purity of cluster: 0.3712923076923077
# Gini index: 0.7450210858486201
# Total images reclustered: 522
#
# Purity of cluster: 0.3723076923076923
# Gini index: 0.7444392866755585
# Total images reclustered: 407
#
# Purity of cluster: 0.3730769230769231
# Gini index: 0.7440019359502512
# Total images reclustered: 317
#
# Purity of cluster: 0.37338461538461537
# Gini index: 0.743770961019902
# Total images reclustered: 280
#
# Purity of cluster: 0.37383076923076924
# Gini index: 0.7434515157630786
# Total images reclustered: 243
#
# Purity of cluster: 0.3740769230769231
# Gini index: 0.7432859168757683
# Total images reclustered: 248
#
# Purity of cluster: 0.37415384615384617
# Gini index: 0.7429793424587432
# Total images reclustered: 242
#
# Purity of cluster: 0.3742
# Gini index: 0.742673098451033
# Total images reclustered: 277
#
# Purity of cluster: 0.37413846153846153
# Gini index: 0.7423650818146613
# Total images reclustered: 277
#
# Purity of cluster: 0.3741076923076923
# Gini index: 0.7420282600312766
# Total images reclustered: 316
#
# Purity of cluster: 0.37635384615384615
# Gini index: 0.741647665593293
# Total images reclustered: 332
#
# Purity of cluster: 0.37886153846153847
# Gini index: 0.7411562620409657
# Total images reclustered: 380
#
# Purity of cluster: 0.3812
# Gini index: 0.7405497360695517
# Total images reclustered: 386
#
# Purity of cluster: 0.3841230769230769
# Gini index: 0.739452350127196
# Total images reclustered: 412
#
# Purity of cluster: 0.3866307692307692
# Gini index: 0.7386483812135882
# Total images reclustered: 409
#
# Purity of cluster: 0.3890923076923077
# Gini index: 0.7377714668614842
# Total images reclustered: 390
#
# Purity of cluster: 0.3911230769230769
# Gini index: 0.7371278327864215
# Total images reclustered: 404
#
# Purity of cluster: 0.3930461538461538
# Gini index: 0.7364465498584828
# Total images reclustered: 406
#
# Purity of cluster: 0.39435384615384617
# Gini index: 0.7362316217782938
# Total images reclustered: 366
#
# Purity of cluster: 0.39535384615384617
# Gini index: 0.7361388364898185
# Total images reclustered: 316
#
# Purity of cluster: 0.39632307692307694
# Gini index: 0.7359392641235841
# Total images reclustered: 289
#
# Purity of cluster: 0.3967846153846154
# Gini index: 0.7360532068328692
# Total images reclustered: 242
#
# Purity of cluster: 0.3969076923076923
# Gini index: 0.736288973617928
# Total images reclustered: 205
#
# Purity of cluster: 0.39721538461538464
# Gini index: 0.7364630980826654
# Total images reclustered: 183
#
# Purity of cluster: 0.3974153846153846
# Gini index: 0.7367307467367831
# Total images reclustered: 149
#
# Purity of cluster: 0.39753846153846156
# Gini index: 0.736931031916648
# Total images reclustered: 117
#
# Purity of cluster: 0.3977538461538462
# Gini index: 0.7371501695595893
# Total images reclustered: 103
#
# Purity of cluster: 0.39795384615384616
# Gini index: 0.7373131404882031
# Total images reclustered: 114
#
# Purity of cluster: 0.3980923076923077
# Gini index: 0.7375611405771388
# Total images reclustered: 117
#
# Purity of cluster: 0.39826153846153844
# Gini index: 0.7377221287019063
# Total images reclustered: 93
#
# Purity of cluster: 0.39855384615384615
# Gini index: 0.7377387775230732
# Total images reclustered: 96
#
# Purity of cluster: 0.3987076923076923
# Gini index: 0.7378252640787918
# Total images reclustered: 77
#
# Purity of cluster: 0.39876923076923076
# Gini index: 0.7379784753791604
# Total images reclustered: 67
#
# Purity of cluster: 0.39884615384615385
# Gini index: 0.7381288727220298
# Total images reclustered: 75
#
# Purity of cluster: 0.3990153846153846
# Gini index: 0.738194751112537
# Total images reclustered: 69
#
# Purity of cluster: 0.39921538461538464
# Gini index: 0.7382173210155071
# Total images reclustered: 71
#
# Purity of cluster: 0.39944615384615384
# Gini index: 0.7381749974185504
# Total images reclustered: 55
#
# Purity of cluster: 0.3995076923076923
# Gini index: 0.7382482925432196
# Total images reclustered: 50
#
# Purity of cluster: 0.39955384615384615
# Gini index: 0.7382640181460548
# Total images reclustered: 40
#
# Purity of cluster: 0.3996
# Gini index: 0.7382629081840154
# Total images reclustered: 26
#
# Purity of cluster: 0.3996461538461539
# Gini index: 0.7382768161130908
# Total images reclustered: 26
#
# Purity of cluster: 0.3997230769230769
# Gini index: 0.738290117965809
# Total images reclustered: 26
#
# Purity of cluster: 0.39981538461538463
# Gini index: 0.7382750919099202
# Total images reclustered: 23
#
# Purity of cluster: 0.3999076923076923
# Gini index: 0.7382593241444442
# Total images reclustered: 27
#
# Purity of cluster: 0.40003076923076925
# Gini index: 0.7382446917631363
# Total images reclustered: 25
#
# Purity of cluster: 0.40013846153846155
# Gini index: 0.7382215136364586
# Total images reclustered: 34
#
# Purity of cluster: 0.40015384615384614
# Gini index: 0.738209723906903
# Total images reclustered: 39
#
# Purity of cluster: 0.40026153846153845
# Gini index: 0.7381739710861517
# Total images reclustered: 48
#
# Purity of cluster: 0.40032307692307695
# Gini index: 0.7381345327033475
# Total images reclustered: 34
#
# Purity of cluster: 0.40033846153846153
# Gini index: 0.7381419299989591
# Total images reclustered: 18
#
# Purity of cluster: 0.40032307692307695
# Gini index: 0.7381789628717119
# Total images reclustered: 19
#
# Purity of cluster: 0.40029230769230767
# Gini index: 0.7382137138313106
# Total images reclustered: 22
#
# Purity of cluster: 0.40032307692307695
# Gini index: 0.7382227735486784
# Total images reclustered: 31
#
# Purity of cluster: 0.4003846153846154
# Gini index: 0.7382143092897366
# Total images reclustered: 26
#
# Purity of cluster: 0.4004615384615385
# Gini index: 0.7382225936973099
# Total images reclustered: 19
#
# Purity of cluster: 0.40047692307692306
# Gini index: 0.7382515984592276
# Total images reclustered: 21
#
# Purity of cluster: 0.4005076923076923
# Gini index: 0.7382708783292465
# Total images reclustered: 25
#
# Purity of cluster: 0.4005846153846154
# Gini index: 0.7382808536633823
# Total images reclustered: 22
#
# Purity of cluster: 0.4007076923076923
# Gini index: 0.7382495335293998
# Total images reclustered: 17
#
# Purity of cluster: 0.40073846153846154
# Gini index: 0.7382806630758035
# Total images reclustered: 17
#
# Purity of cluster: 0.40076923076923077
# Gini index: 0.7382879940910113
# Total images reclustered: 13
#
# Purity of cluster: 0.40076923076923077
# Gini index: 0.7383012828187535
# Total images reclustered: 6
#
# Purity of cluster: 0.4007846153846154
# Gini index: 0.7383075384549781
# Total images reclustered: 4
#
# Purity of cluster: 0.4007846153846154
# Gini index: 0.7383114908847996
# Total images reclustered: 3
#
# Purity of cluster: 0.4007846153846154
# Gini index: 0.7383211040994883
# Total images reclustered: 3
#
# Purity of cluster: 0.40076923076923077
# Gini index: 0.7383430022560548
# Total images reclustered: 3
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.738349049305644
# Total images reclustered: 2
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383550556353254
# Total images reclustered: 1
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.738363989878864
# Total images reclustered: 2
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 1
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Purity of cluster: 0.4007538461538461
# Gini index: 0.7383621293507497
# Total images reclustered: 0
#
# Done

# %%
print("Starting KMeans.....\n")
clusters = KMeans(20)
print("Done")
# Out:
# Starting KMeans.....
#
# Purity of cluster: 0.5029846153846154
# Gini index: 0.6082286024309501
# Total images reclustered: 15023
#
# Purity of cluster: 0.5574615384615385
# Gini index: 0.5570924760268444
# Total images reclustered: 9848
#
# Purity of cluster: 0.5971076923076923
# Gini index: 0.5228584785185385
# Total images reclustered: 6795
#
# Purity of cluster: 0.6207846153846154
# Gini index: 0.50240008504275
# Total images reclustered: 5001
#
# Purity of cluster: 0.6395076923076923
# Gini index: 0.4864267182885696
# Total images reclustered: 4100
#
# Purity of cluster: 0.6533230769230769
# Gini index: 0.4739666641369416
# Total images reclustered: 3483
#
# Purity of cluster: 0.6631538461538462
# Gini index: 0.4644925930649321
# Total images reclustered: 2911
#
# Purity of cluster: 0.671
# Gini index: 0.45672528513186383
# Total images reclustered: 2578
#
# Purity of cluster: 0.6784
# Gini index: 0.4495790025635899
# Total images reclustered: 2184
#
# Purity of cluster: 0.6851538461538461
# Gini index: 0.44246375163596224
# Total images reclustered: 1855
#
# Purity of cluster: 0.6901538461538461
# Gini index: 0.43696027292971906
# Total images reclustered: 1684
#
# Purity of cluster: 0.6941076923076923
# Gini index: 0.4321721271619791
# Total images reclustered: 1566
#
# Purity of cluster: 0.6979076923076923
# Gini index: 0.42786194652884335
# Total images reclustered: 1414
#
# Purity of cluster: 0.7007538461538462
# Gini index: 0.4242688427947858
# Total images reclustered: 1248
#
# Purity of cluster: 0.7028
# Gini index: 0.42160851793382803
# Total images reclustered: 1190
#
# Purity of cluster: 0.7043230769230769
# Gini index: 0.4194494859444603
# Total images reclustered: 1059
#
# Purity of cluster: 0.7053538461538461
# Gini index: 0.4174382527696683
# Total images reclustered: 956
#
# Purity of cluster: 0.7060923076923077
# Gini index: 0.4160642173772607
# Total images reclustered: 853
#
# Purity of cluster: 0.7063692307692307
# Gini index: 0.4149471252875159
# Total images reclustered: 783
#
# Purity of cluster: 0.707123076923077
# Gini index: 0.41324684936396744
# Total images reclustered: 661
#
# Purity of cluster: 0.707276923076923
# Gini index: 0.41206076714411033
# Total images reclustered: 587
#
# Purity of cluster: 0.7074461538461538
# Gini index: 0.41090064831459056
# Total images reclustered: 557
#
# Purity of cluster: 0.7074615384615385
# Gini index: 0.40997096180548304
# Total images reclustered: 448
#
# Purity of cluster: 0.7075384615384616
# Gini index: 0.40937748405158014
# Total images reclustered: 364
#
# Purity of cluster: 0.7076307692307693
# Gini index: 0.408795137865899
# Total images reclustered: 328
#
# Purity of cluster: 0.7075692307692307
# Gini index: 0.4085055427969899
# Total images reclustered: 310
#
# Purity of cluster: 0.7073230769230769
# Gini index: 0.4082894726550136
# Total images reclustered: 257
#
# Purity of cluster: 0.7071692307692308
# Gini index: 0.4080267177113725
# Total images reclustered: 248
#
# Purity of cluster: 0.7071692307692308
# Gini index: 0.40777687043390154
# Total images reclustered: 204
#
# Purity of cluster: 0.707123076923077
# Gini index: 0.4076442092556041
# Total images reclustered: 173
#
# Purity of cluster: 0.7071384615384615
# Gini index: 0.4075319848603118
# Total images reclustered: 170
#
# Purity of cluster: 0.7070307692307692
# Gini index: 0.4073956570362718
# Total images reclustered: 158
#
# Purity of cluster: 0.7070153846153846
# Gini index: 0.4072125994266896
# Total images reclustered: 148
#
# Purity of cluster: 0.7071538461538461
# Gini index: 0.4069938931394258
# Total images reclustered: 137
#
# Purity of cluster: 0.7072461538461539
# Gini index: 0.4066851063920224
# Total images reclustered: 124
#
# Purity of cluster: 0.7072153846153846
# Gini index: 0.40669112717587885
# Total images reclustered: 115
#
# Purity of cluster: 0.7074
# Gini index: 0.40650985782015886
# Total images reclustered: 121
#
# Purity of cluster: 0.7071846153846154
# Gini index: 0.40673327942585863
# Total images reclustered: 116
#
# Purity of cluster: 0.7072307692307692
# Gini index: 0.406570379448698
# Total images reclustered: 117
#
# Purity of cluster: 0.7072615384615385
# Gini index: 0.40644106542367575
# Total images reclustered: 99
#
# Purity of cluster: 0.7072461538461539
# Gini index: 0.406380145851734
# Total images reclustered: 60
#
# Purity of cluster: 0.7072615384615385
# Gini index: 0.40627591741623387
# Total images reclustered: 55
#
# Purity of cluster: 0.7073538461538461
# Gini index: 0.4060829861982272
# Total images reclustered: 35
#
# Purity of cluster: 0.7073076923076923
# Gini index: 0.40608090365425364
# Total images reclustered: 34
#
# Purity of cluster: 0.7071384615384615
# Gini index: 0.40616708162673526
# Total images reclustered: 39
#
# Purity of cluster: 0.707123076923077
# Gini index: 0.40619888935446175
# Total images reclustered: 28
#
# Purity of cluster: 0.7071384615384615
# Gini index: 0.40622406111417214
# Total images reclustered: 21
#
# Purity of cluster: 0.7071076923076923
# Gini index: 0.40629219455781107
# Total images reclustered: 21
#
# Purity of cluster: 0.7071076923076923
# Gini index: 0.4062895073128506
# Total images reclustered: 16
#
# Purity of cluster: 0.7071538461538461
# Gini index: 0.4063046923893378
# Total images reclustered: 18
#
# Purity of cluster: 0.707123076923077
# Gini index: 0.4063214677750787
# Total images reclustered: 22
#
# Purity of cluster: 0.7071846153846154
# Gini index: 0.4063085669442852
# Total images reclustered: 11
#
# Purity of cluster: 0.7072153846153846
# Gini index: 0.4062974428487404
# Total images reclustered: 9
#
# Purity of cluster: 0.7071846153846154
# Gini index: 0.4063382294032976
# Total images reclustered: 8
#
# Purity of cluster: 0.7072
# Gini index: 0.40630929459580367
# Total images reclustered: 5
#
# Purity of cluster: 0.7072
# Gini index: 0.40631109931085935
# Total images reclustered: 7
#
# Purity of cluster: 0.7072
# Gini index: 0.4063126562344013
# Total images reclustered: 8
#
# Purity of cluster: 0.7071846153846154
# Gini index: 0.40631027317588175
# Total images reclustered: 8
#
# Purity of cluster: 0.7071846153846154
# Gini index: 0.40630869348696536
# Total images reclustered: 4
#
# Purity of cluster: 0.7071384615384615
# Gini index: 0.40632805629194113
# Total images reclustered: 7
#
# Purity of cluster: 0.7071538461538461
# Gini index: 0.40632270811002036
# Total images reclustered: 6
#
# Purity of cluster: 0.7071384615384615
# Gini index: 0.406347865004998
# Total images reclustered: 9
#
# Purity of cluster: 0.7072153846153846
# Gini index: 0.40633410732345987
# Total images reclustered: 11
#
# Purity of cluster: 0.7072615384615385
# Gini index: 0.40629861524119026
# Total images reclustered: 10
#
# Purity of cluster: 0.7073384615384616
# Gini index: 0.40626683310438455
# Total images reclustered: 9
#
# Purity of cluster: 0.7073230769230769
# Gini index: 0.4062842897767342
# Total images reclustered: 6
#
# Purity of cluster: 0.7073230769230769
# Gini index: 0.40630363109222895
# Total images reclustered: 5
#
# Purity of cluster: 0.7073230769230769
# Gini index: 0.4063198722346681
# Total images reclustered: 3
#
# Purity of cluster: 0.7073076923076923
# Gini index: 0.4063237803465276
# Total images reclustered: 1
#
# Purity of cluster: 0.7073076923076923
# Gini index: 0.4063237803465276
# Total images reclustered: 0
#
# Done
