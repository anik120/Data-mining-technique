# %%
import ast
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn import mixture
import itertools, operator
import scipy.stats

# %%
n_components = 20
n_top_words = 50

# %%
whole_docs = []
whole_doc_labels = []
whole_doc_id = []
file = open("whole_dataset.txt", 'r')
for line in file:
    line = ast.literal_eval(line)
    whole_doc_id.append(line[0])
    whole_doc_labels.append(line[1])
    whole_docs.append(line[2])

# %%
docs = []
doc_topics = []
doc_id = []
file = open("sample_dataset.txt", 'r')
for line in file:
    line = ast.literal_eval(line)
    doc_id.append(line[0])
    doc_topics.append(line[1])
    docs.append(line[2])

# %%
topic_words_dict = {}

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        topic_words_dict[topic_idx] = message.split()[2:] 
        print(message)
    print()

# %%
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(whole_docs)
print("Done")
# Out:
# Extracting tf features for LDA...
# Done

# %%
print("Fitting LDA models with tf features...")
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)
print("Done")
# Out:
# Fitting LDA models with tf features...
# Done

# %%
print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
# Topic #0: 10 israel 12 25 15 20 11 jesus 14 13 16 00 17 18 lord israeli 30 19 arab 22 21 28 myers 26 40 23 27 24 john jewish 50 31 vs 29 god st 34 33 arabs 35 38 son 60 42 37 insurance shall 32 36 elohim
# Topic #1: turkish atf taxes msg printer flyers energy print husband apple canon girls caps raid baptism morris injury laser coach hp dust teacher tied paper edu kidney ii boston establishment wright dry dept armored outlets district ball struck preserve protest aluminum detectors michael mothers discharge mac coat clark outlet virginia bathroom
# Topic #2: car 000 water miles south cars radio oil british engine air road power new vehicle years earth cold light auto city station professor fuel gm york high resistance vancouver pope radar palestine holocaust probe canada clutch ground 1914 wiring north chicago street great lights activities heavy american room bmw montreal
# Topic #3: hiv zone lebanon candida clinical surgery wounded hicnet contest sharks defensive infected physician intercourse boswell winners phillies vaccine malaria calcium infectious perpetrated shelling allergic diabetes bernadette antibiotic supplementation vaginal sinus antibiotics vaccines deaf vagina disturbing intentions sect ioccc obfuscated systemic infants thex cholesterol loser motions animals mmwr judges invite blooms
# Topic #4: armenian armenians turkey armenia turks azerbaijan ottoman istanbul villages azerbaijani argic serdar azeri baku sumgait karabakh mamma reno kurds ankara azerbaijanis ve cyprus azeris jupiter karabagh massacres tartars nagorno tartar anonymity ermeni turkiye extermination sdpa karina asala erzurum dro arf osmanli anatolia kurdish arrested aiu marina lyuda cleansing agdam massacred
# Topic #5: arms firearms weapons agents congress law militia attorney bullock government territory muslims iranian kinsey 1978 export rights define briefing batteries defined events commerce launches escrow croats embargo saudi arabia deputy bds independence clause expose ezekiel drunk briefed gcc confidential committed libxmu event client prohibition goods thathe disobedience reserves astronaut copperud
# Topic #6: file windows dos use program ms files image window color xx display version jpeg output gif format os screen run programs entry using mouse software error images pc need fonts size microsoft disk code info mac read manager driver user memory available machine section colors font mode type write int
# Topic #7: drive use card chip used bit power new scsi need hard data price does speed work like disk problem bus launch high know video sale using monitor pc board civil computer buy cost mac software drives device 16 serial ram hardware low help memory looking 50 10 cable solar fast
# Topic #8: edu space com mail available information university data list ftp 1993 send nasa server email sun pub april software new cs program address graphics internet ca anonymous 10 version source 00 include research faq number contact ed computer based mit systems 93 fax set info code la shuttle pp application
# Topic #9: team adl bos vitamin division firearm espn amp revolution braves pitcher pitching jersey sox clayton weaver 1974 thomas hitter jays pitchers batting defamation retinol kent edmonton mets weiss height pipes gut clemens aunt cubs dodgers educated yankees rbi rookie dd taylor mvp width dale mosque seattle gurvitz anderson xmu catcher
# Topic #10: period jehovah play power red minister _____ __ blue second penalty green printf shameful commandments leads n3jxp andgeb dsl train pluto gifts lindros turan dose succeeded statistic gilmour soderstrom nejm aggression manned intake recchi promiscuous _______ winnipeg amour argv propane routinely brind args bce liturgy ahmadiyya sodom lesbian servicing sez
# Topic #11: clipper season nsa keys san escrow jose crypto shots nra tom wiretap phones ron tragedy nist era initiative liver plate nutrition communications arrogance defeated denning balloon suck arena loves ncsl das org tampa duo overtime walks agencies wiretaps skipjack shaft motorcycle escrowed alarm nerve cubs pitches congregation netcom rhetoric racing
# Topic #12: pts chronic 1920 intellect syndrome deficit hawks 1975 det lyme decade pms goverment magnesium cement inning kirlian aaron smokeless pursuing hepatitis herodotus disc vain streak dennis riot coli jokes anas outbreak div o157 sho udel pocklington foods shea tangible ruined kkk intentional oates supportive precognition inflammation hawerchuk royals aura federation
# Topic #13: stephanopoulos nhl buf chi cal 03 rangers pens homicide injuries oname playoff elias africa fprintf homicides rochester penguins rockefeller forsale trinity oilers gretzky check_io stderr allah jagr eof_not_ok martian stl colormap adventures roberts perpetrators rama baden assaults anania bowman whalers kleck messier sisters confess malcolm buddy sporting keenan gainey bison
# Topic #14: palestinians buffalo zoroastrians leafs bruins sabres islanders nyi lemieux persian shouted helicopter fuhr diagnosed motorcycles wsh yassin goalie tribe settlement revolt mandatory nyr irgun hire sheikh hfd diana canucks zoroaster deir restaurant shostack twins vernon potvin cgy ceremony bestiality selanne adamadam mogilny zoroastrian kuwaiti whatthey logo habs goddess attacker stabbed
# Topic #15: cx bh ar bd dee w7 ah eff s1 hz km tb kt si al c_ sk edm bm lk s2 kk 17 uw t7 ck rm ss ma 86 cadre b6 sq te chz mc sb rw mm sp 7u air fm ww sy a7 k8 ab hm hr
# Topic #16: magi 1st man rsa appears ripem force frank rider acid men origin aircraft balcony 80 rkba new cramer comics comet black hulk libertarians wolverine weapon miller 1919 physicians 10 1923 1982 reincarnation chromium signed repent sabretooth ciphers liefeld gazans zoroastrianism appearance ali ssf thousands oort pem decenso cryptographic cryptology 1962
# Topic #17: people don just like know think time god does did good said way say right make ve believe going want use new point really government years year things ll let question come didn fact used world long sure work doesn problem day mr better law state case life read need
# Topic #18: cancer orbit lunar rocket lands simms handguns dr slot breast corpses antenna orbiter gant corpse clinic bodies flyby artillery lamp french historians dietary mint funding cryptanalysis ssto secrets simm centaur interstellar therapies colonel lander astronauts vika ranger billboard umpire investigated allergy clinical surgeon billboards contempt glucose authentication cox cotton laboratories
# Topic #19: ax max g9v b8f a86 pl 145 1d9 1t 0t 34u 75u 3t giz 2di bhj 2tm wm 7ey bxn 0d gk 6ei sl 9v 6um qq bj 34 m3 qax tq wt okz 45 04 3l g9 b4q ql kn tm 5u m_ nrhj d9 b8e 7kn 9f flew

# %%
topic_words_prob_dict = {}

# %%
lda.components_ /= lda.components_.sum(axis=1)[:, np.newaxis]
for i in range(n_components):
    topic_words_prob_dict[i] = sorted(lda.components_[i])[::-1][:n_top_words] 
    print("Topic ",i,": ", sorted(lda.components_[i])[::-1][:n_top_words])
# Out:
# Topic  0 :  [0.01954601605045436, 0.017362991786550895, 0.01612802089995114, 0.015491786803195889, 0.014130983417542608, 0.013938671022748872, 0.013665295321369845, 0.01319606657551081, 0.012470437867539751, 0.010659587130202115, 0.010490246737488438, 0.010327353307400006, 0.010152412218925006, 0.009972607600043063, 0.009381688131825092, 0.00937807966774125, 0.009238428697868109, 0.008981147749734214, 0.007718464986846207, 0.007431084824530577, 0.007410142967604377, 0.0073693273544623876, 0.007290161363043345, 0.007216093683073148, 0.007052593314617261, 0.006969794461210755, 0.0062915020175743136, 0.00626370371575111, 0.006034398207208108, 0.006025074306446298, 0.0054849312464691725, 0.005448951469361569, 0.00514916634116765, 0.004862128123941317, 0.004797224448347936, 0.004668863819701198, 0.004333482921848851, 0.004329173325040134, 0.004293069765054766, 0.004254993927514811, 0.004027048721446008, 0.003965598241877788, 0.003762786560413856, 0.0037179969325351796, 0.003548528886180912, 0.003490211018707502, 0.0033979226334365873, 0.0033341148321370945, 0.003304745610582009, 0.0032815365128914214]
# Topic  1 :  [0.03627461086163166, 0.008526741522814603, 0.007183275912144488, 0.007150356006352117, 0.00618112863538186, 0.005178935198814551, 0.005123686245530229, 0.005009374860829381, 0.005004801130191834, 0.004863626638780565, 0.004840707104623438, 0.004816472156557514, 0.004777884409454035, 0.004419590392613818, 0.004351627736642521, 0.004336846239353054, 0.004232829188576486, 0.004206359389365438, 0.004060525935421273, 0.003968647498220531, 0.003787764269026839, 0.003648552845442446, 0.003610869683222078, 0.003383022774527053, 0.0033802596652973593, 0.0033376734079476633, 0.0032045939343561957, 0.0030537492140398407, 0.0029430037166670855, 0.002894985828710322, 0.002845134764196581, 0.0028187144815376344, 0.00279446274081527, 0.002685908664972809, 0.002672936879714011, 0.00260979335193899, 0.0025868361404363465, 0.0025860435917281106, 0.002492930436628683, 0.002390676051972636, 0.002357861685097031, 0.0022726162338235095, 0.0021450466005359155, 0.002104705429109737, 0.002092461250116552, 0.0020716885076677875, 0.0020386635174493547, 0.002026755350762205, 0.0019886224101437603, 0.0019872826172126915]
# Topic  2 :  [0.0180599447096806, 0.013266630809571592, 0.008476340608859857, 0.006539665953394818, 0.005988603995955835, 0.0057802330228030425, 0.005725207626534602, 0.005622971154863338, 0.005581628873691731, 0.005360967268020463, 0.005245051735613971, 0.004956072975530818, 0.004395677149290653, 0.004034120794803015, 0.0036547810627027663, 0.003588481938689816, 0.0035360407520620856, 0.003387124139844765, 0.00336820511134353, 0.0033249172832189875, 0.003298998070842777, 0.003255452830612406, 0.003118726121295546, 0.0030997531328500086, 0.0030484461820877063, 0.0030089251626475, 0.0029583415894166173, 0.002954033826467633, 0.0029491931593237366, 0.0028221312839088603, 0.0027989402362623528, 0.002798402034817128, 0.0027831976008828693, 0.00271309922860817, 0.002683102990571927, 0.002664261315476641, 0.0025953033550878174, 0.0025424150583787416, 0.0025249931907707526, 0.0024944224485459027, 0.0024711006808669717, 0.0024210210997496952, 0.0024144127751400206, 0.002403876590315675, 0.0023982508913157775, 0.0023890078463907963, 0.002332115245955468, 0.0023147305689343966, 0.002279616174436811, 0.002248839583400813]
# Topic  3 :  [0.018544548938859696, 0.011571228422336684, 0.009367405953151683, 0.008707413917921566, 0.008550173286064899, 0.007124774526941908, 0.0069901891436428025, 0.006335636388560007, 0.005485053591455344, 0.005433688650838353, 0.005153725866138395, 0.0048821058335211465, 0.00465321101149343, 0.003901930119273626, 0.0037248526424296675, 0.00371932076244125, 0.0037057428124783387, 0.0033415501483347403, 0.003214074893322715, 0.003210123210230666, 0.0031707126626057468, 0.00308022800474745, 0.0029993205675292703, 0.0029254578624208966, 0.0028830891419563856, 0.002845326689443986, 0.002821425413247475, 0.0028147117184895943, 0.002712476683954272, 0.0026205108538755696, 0.002606727416670184, 0.0025387761484903476, 0.0024953067234830682, 0.002479149716853621, 0.002457792994822544, 0.0024225679977856905, 0.0024191558304838315, 0.002377567088882846, 0.002372802770825937, 0.0023034273052145154, 0.0022786012138505253, 0.002276390384513636, 0.002209848975461513, 0.002108450154606815, 0.0020184927065098374, 0.0020068000647093733, 0.002005762172946193, 0.001993068358320636, 0.0019712046405960812, 0.001962140248116744]
# Topic  4 :  [0.04150450296042376, 0.035075669206005605, 0.017751447914619547, 0.015377327891412334, 0.013479494513014395, 0.011467969375324679, 0.009089197197085489, 0.008575869545828178, 0.007909016397017, 0.007068432898845709, 0.006949847287789512, 0.006693902923862303, 0.006202201466557203, 0.005966419560635295, 0.005656722748479488, 0.0053952247923467304, 0.005175679808520867, 0.004775947952701446, 0.004761250649355366, 0.004639893196383377, 0.0045402594365478634, 0.003969365258076221, 0.003706594568020122, 0.0035681744289896805, 0.0034767473486627194, 0.003345668820660211, 0.003188424538499674, 0.003155262569288301, 0.003074143794137463, 0.0030327045775130844, 0.0029465800758758645, 0.002938734321627502, 0.0029232500178027554, 0.002874027513752288, 0.002834713867187821, 0.0028283790786052467, 0.002651380771218337, 0.0026347683758865064, 0.0025894470404555303, 0.0024389198957556276, 0.002369400552304284, 0.0023438373703514597, 0.0022755729787080747, 0.0021897824399159122, 0.002155301189579002, 0.002133790438015298, 0.0021052042499644288, 0.002092692306764698, 0.002003597779194373, 0.0019672549428007757]
# Topic  5 :  [0.01874429862208578, 0.017058468832312778, 0.013792516115934638, 0.013536814056578382, 0.012431254991864099, 0.011132073843495714, 0.009509658616054522, 0.007701345062945666, 0.007575642035182211, 0.007501264229206414, 0.006207366505131406, 0.00598870088954418, 0.005948838277023308, 0.005396612206844074, 0.004347394107050199, 0.004284336834019424, 0.004114400388272509, 0.003977375868109604, 0.003511857402926262, 0.003418976474730684, 0.003249583062599014, 0.0032331264629647007, 0.003025024103664727, 0.0030237733506431556, 0.0029417482646665154, 0.002926539050842128, 0.0027398668229422353, 0.0026578358882243833, 0.002633655597171437, 0.002584881961191834, 0.002526475983550819, 0.002442780577299141, 0.002368229388892965, 0.0023301330170574313, 0.0022624421653817442, 0.002240831078573335, 0.002028525455330185, 0.001991317541006762, 0.0019632782002045952, 0.001935436125869034, 0.0019273747859891441, 0.0019133454476894533, 0.0018985241287487672, 0.00189174815939266, 0.0018288783773260907, 0.001805512558532378, 0.00179772672607719, 0.0017659264048998367, 0.0017626989073815315, 0.0017605705942745325]
# Topic  6 :  [0.03311030485574547, 0.02674722472239485, 0.02114997044746215, 0.015973528763782798, 0.015683016446696386, 0.014088558319744615, 0.012314394355133956, 0.011718769974812618, 0.011096138546659286, 0.009606893467008425, 0.008831535032659208, 0.008480807195336398, 0.00773582514756777, 0.007695013252372439, 0.007333650337767162, 0.0070605512554992615, 0.0069512259297263715, 0.00672627648430381, 0.006703183663993252, 0.006092913371067064, 0.0060221608138751465, 0.006010167542287514, 0.0058468968208537754, 0.005552822669075556, 0.005530197164921466, 0.0053945902864356325, 0.005032741961014239, 0.004786450944991565, 0.004758073781493304, 0.004496620048529545, 0.004327897170142174, 0.004261291697297957, 0.004105829599394831, 0.004103626507296018, 0.00409204048401627, 0.004057673190416287, 0.00400035358199729, 0.003956695705807924, 0.003929908486851459, 0.003923861398529897, 0.0038825197921900346, 0.0038241201473792463, 0.003769132931587173, 0.003726350738670348, 0.003714988831803396, 0.0036885476224229503, 0.003562501646191967, 0.0035560977779406124, 0.003405783931394749, 0.00338879294461973]
# Topic  7 :  [0.010243087261121145, 0.0071104473198484825, 0.007049990244205467, 0.006647704055748911, 0.006480912903152209, 0.006384612969466135, 0.0055725391955698264, 0.005277109874042004, 0.004902386428628604, 0.004837110376604581, 0.0047645105301737335, 0.0046367459090523285, 0.004633059267950906, 0.004605665638550189, 0.004598613271803321, 0.004543686076930945, 0.004535383699844085, 0.004240397149446287, 0.004156600967728922, 0.0038587438577141206, 0.0037955618375315856, 0.0037352892207774767, 0.0037264816255215866, 0.003726105934244943, 0.003596435666778889, 0.003513159154850891, 0.003506709929102065, 0.0034436846355774585, 0.0034319262311885697, 0.00339792650195649, 0.003335766985788636, 0.003301799477795259, 0.0031170121362694447, 0.00294825404462593, 0.0029012558414695366, 0.0028942432835673717, 0.002856148179672845, 0.0028410895412468054, 0.002804227577331024, 0.002718135851628427, 0.0027036165422011237, 0.002638025131381235, 0.002635655651643537, 0.0026200211114154777, 0.002619152429001638, 0.002597186949775436, 0.002592610715332245, 0.0025742278527197877, 0.0025627653428990874, 0.002558920446185883]
# Topic  8 :  [0.012847866411695446, 0.0074746441812577466, 0.005882864105093255, 0.005704144420836614, 0.005281490852405329, 0.005071189384582027, 0.004500201347189915, 0.004451059006915087, 0.004318479290779896, 0.0038574742833599367, 0.0038003260743301203, 0.0037697744139343356, 0.0033468255918662486, 0.0032069639662091307, 0.003167473878401954, 0.0030975147998548013, 0.0030882512048416226, 0.0030804334177453887, 0.0029473105662527624, 0.0029361690610551585, 0.0026960791391159628, 0.0026144767257363, 0.0026059468913115676, 0.002551276854405935, 0.0025157784359421008, 0.0025138582114912454, 0.002480081525343209, 0.002417470732397372, 0.0023833487702818647, 0.002350693559246166, 0.0023104742589206474, 0.0022787535639071056, 0.0022422967343288707, 0.002178096057549243, 0.0021609440479826744, 0.0021565227581860002, 0.002150729790183795, 0.002134133755821101, 0.002102181322034446, 0.002099025182293521, 0.0020798171684785543, 0.002055475767323896, 0.0020371106508116094, 0.0020278998775079033, 0.002023732119685311, 0.0019948320346266993, 0.0019750601821684976, 0.001915220729985335, 0.0019145255004334111, 0.0019139901562531133]
# Topic  9 :  [0.04877595283583824, 0.016725953737700666, 0.01392837678940956, 0.011816425599164746, 0.010487221925927758, 0.010075483305522165, 0.008616056720220339, 0.007358171319837775, 0.006496407485212051, 0.00647495347394681, 0.006442396285960489, 0.006167466066201318, 0.006014458505470857, 0.005457905453066991, 0.00545691507276384, 0.005365205772190587, 0.00501447654339554, 0.004556854873187039, 0.004253517032166353, 0.0038229257067107906, 0.0038177531601114164, 0.0036730402718583776, 0.003541578667184152, 0.003410151714043394, 0.0033819016075794643, 0.0033594221293431334, 0.00335434174629371, 0.003339870342893992, 0.003317280213787384, 0.003255287695339279, 0.003210405210430117, 0.0030341713181968174, 0.0029601699560450373, 0.0029202489266797523, 0.002838379753919841, 0.0027490805529424367, 0.0027378918439404888, 0.0027016130348671867, 0.0026875593317851015, 0.0025984459073076856, 0.0025531183829959623, 0.002526724436058683, 0.002524516637624381, 0.002449451817465571, 0.0024419852042741044, 0.0024072145834199373, 0.002316919903126226, 0.002270612307405341, 0.0022488409482094795, 0.0022333550708532857]
# Topic  10 :  [0.03010940283855854, 0.02060459355183286, 0.018313531519718387, 0.012133135234985708, 0.012108149692922848, 0.01028438326028334, 0.01015334298898388, 0.008708293608547664, 0.007612387944007893, 0.007216126358335083, 0.006896894017382291, 0.006589876515255363, 0.0062660866621292366, 0.006163934769373111, 0.00594752021107348, 0.00548402027929277, 0.005404070481579255, 0.0053347701897506145, 0.0053320789289505255, 0.004966870737175993, 0.00477344405152298, 0.004288406436671742, 0.0042740797583517495, 0.003965654562460228, 0.0035251395493404317, 0.003478175288200262, 0.0034444885527906326, 0.0032704029488830437, 0.0031834016104880843, 0.0030960993028355433, 0.003050925647410552, 0.003049753967968371, 0.002964320565398728, 0.002878265204714951, 0.002797814172045718, 0.002725952833625145, 0.0026795703061869573, 0.002592743065044326, 0.0025856525146721356, 0.0025552043171786134, 0.002463286111648168, 0.002362293569591973, 0.0023441754408027766, 0.0021698345670238613, 0.002141452514780428, 0.0021078763780286243, 0.002063360426146744, 0.00204692084688087, 0.0020384852544593087, 0.0020346914239172125]
# Topic  11 :  [0.027246232467042678, 0.02410677048340891, 0.014294529120733035, 0.013784552513182745, 0.011917246341477306, 0.009895648171102436, 0.009732177278686993, 0.008245808002446052, 0.007218583617575867, 0.007118960863966216, 0.006830456561788285, 0.006549158244378959, 0.006531522409927853, 0.0064473890406874365, 0.006247790903476118, 0.005587394494429916, 0.005443809574482849, 0.005439567501482819, 0.004858347167745236, 0.004603366167511223, 0.004222560754428996, 0.003965315780442841, 0.003939067163055544, 0.0037028021204018324, 0.0035887565425363546, 0.003374626007819267, 0.0032375643605812854, 0.003214448819866421, 0.0032116520653524684, 0.0031969119432811704, 0.0030530473410846923, 0.0029940856131302662, 0.0028714113409525634, 0.0028484341949620373, 0.0026180157739081377, 0.002483980141616061, 0.002384212018485429, 0.00237738130126854, 0.002339687207147251, 0.0023185604018226744, 0.0023066061837674723, 0.0022025859738128385, 0.002202385231194129, 0.002190096581986683, 0.0021857503493548395, 0.0021782958636833312, 0.0020687460719071037, 0.0020482950960143582, 0.002009271644918818, 0.0020000630381275344]
# Topic  12 :  [0.02376185043016462, 0.010553465565696061, 0.009971092204110521, 0.008654185987149008, 0.008013980871716562, 0.007837493785933364, 0.00666905317430862, 0.006642286961527945, 0.006412586235315024, 0.006230115677887592, 0.00520472802489759, 0.004929835439407091, 0.004814711802248021, 0.004704094840055157, 0.004279732570639889, 0.0041839408155895375, 0.004015242260142463, 0.00393549403946754, 0.0039231029051238165, 0.0038933448466309728, 0.003699709822538998, 0.0036584113964759366, 0.0036493595545268056, 0.0034669432568382725, 0.003426514220645543, 0.0034212214276167804, 0.0032318599234502413, 0.0031720193965477893, 0.0031000192128358573, 0.0028577495757604585, 0.0028247156403765493, 0.002804678926836435, 0.002803606188352997, 0.0027335298845226385, 0.002612505078352815, 0.0024877180097268472, 0.002478331357474422, 0.0024529927468573826, 0.0024250759223919996, 0.002401721840795226, 0.0023915193771985106, 0.002383415533503853, 0.0023640273307990937, 0.0023479737987776765, 0.0022833838012931364, 0.0022801842206227304, 0.0022372961581214462, 0.002231672292479434, 0.0022316126198647, 0.002231302528521186]
# Topic  13 :  [0.053092822731384284, 0.019189829733609547, 0.016596631535799003, 0.015295692949071519, 0.014531201619281852, 0.01352025885217813, 0.01281935206692448, 0.0077718362347073125, 0.006864748441153483, 0.006504333120792376, 0.0064117292044090736, 0.006091575560496297, 0.0059563433812741574, 0.005370293913567045, 0.005368665178802359, 0.00479026780653164, 0.004723019342256299, 0.004715751404738688, 0.004665055673964231, 0.004159388174990676, 0.004096205016687493, 0.004016240177769606, 0.0038376735089498256, 0.003579641854290139, 0.003571421119902805, 0.0034111896580879043, 0.0033917963948574136, 0.0032966783103591953, 0.0032282475502342263, 0.003182710461467353, 0.003156403308107672, 0.0029983886981370176, 0.002929874554835809, 0.0028755397104393387, 0.0028160730615656676, 0.0027956542406308584, 0.0027808556102211224, 0.002649745630009298, 0.0024274496784290624, 0.002344775458109148, 0.0023122704301108544, 0.0022997807581788586, 0.0022347574880798356, 0.002213335120064423, 0.002183185095881541, 0.002134379938274964, 0.0021018423183024795, 0.002041040680962299, 0.0019634502336074934, 0.0019631636046650407]
# Topic  14 :  [0.013348372677354394, 0.010416843687494825, 0.01038678476530663, 0.008670341756506581, 0.007784729243313144, 0.007202870097666444, 0.006866721026816496, 0.006617004902435285, 0.005726489807776117, 0.005091705220956459, 0.004882843102800995, 0.004500895225136882, 0.004482684165920359, 0.004478042379707683, 0.004376435709554608, 0.004358233130811596, 0.004335214815301945, 0.0041122979575802755, 0.004088041608002909, 0.003972126580825137, 0.003837862945873771, 0.003628476779872836, 0.0036213734503903446, 0.003600211794427753, 0.003464925692937613, 0.003439104690370979, 0.0034132655990244537, 0.0033990074458107714, 0.003253294014599243, 0.00321942624523701, 0.003177026766065656, 0.0029474524145831978, 0.0029469017520234184, 0.002943961124726606, 0.002876528903480951, 0.0028302248849868556, 0.002829008803514414, 0.0028107745909287146, 0.0027194037818495847, 0.002589351673043101, 0.0025273533924662474, 0.0024874799235197207, 0.002481479175128628, 0.002480930949408096, 0.002312829985990725, 0.002296230330074201, 0.002286454053357083, 0.002268672327632411, 0.002216093441669886, 0.00219290377210954]
# Topic  15 :  [0.004803115702017482, 0.003952736348052221, 0.0038941975040375732, 0.0036462411636615628, 0.003006628631210288, 0.0028998998191042714, 0.0028952365972702266, 0.002821643594810847, 0.002671277275362487, 0.002652073117858543, 0.002593303455034952, 0.002484777428330628, 0.002435852359482419, 0.0024323726681863603, 0.0022322680411204585, 0.002173795938757676, 0.002170686613187109, 0.002138781645468218, 0.0021343703332699923, 0.0020799638338504984, 0.0020774792792681972, 0.002071156839133682, 0.0020360576802016094, 0.002022373555778932, 0.0020079198004458966, 0.001989396781343321, 0.0019724717823448286, 0.001964490507577634, 0.0018551247242978466, 0.0018474633434707197, 0.0018427907935486172, 0.001761688710178419, 0.001753616264335793, 0.0017328789863626317, 0.00171710431238144, 0.0016696119290228078, 0.001652185677861687, 0.0016391981554663053, 0.0016306422261305764, 0.0016070765702878773, 0.0015687000882528006, 0.0015682980944812875, 0.0015502939665663854, 0.001541598704644015, 0.001515202716976498, 0.0015097645853329237, 0.0015034002256710027, 0.0014962385981361263, 0.0014847511433617436, 0.0014761388753920912]
# Topic  16 :  [0.014591560114690467, 0.013972213892386134, 0.012336789229617362, 0.009673275686331823, 0.009030621272205107, 0.008973749857022872, 0.008623910848197875, 0.00652606041537399, 0.006406115580689294, 0.006281958524962654, 0.0062077672401920905, 0.006071440069677461, 0.006068221267446014, 0.006032960703696498, 0.005644865184655542, 0.005434604280952026, 0.0050599954650067235, 0.004989769280498352, 0.004939495807529974, 0.00487653070571818, 0.004760871263821364, 0.004567284710430397, 0.0045247180435061705, 0.004446172099527423, 0.004443319954831335, 0.004307888177862354, 0.004299722246211839, 0.004281952900806614, 0.004245398652007266, 0.004238665544332103, 0.003973516506610432, 0.003964293484749061, 0.003952280333139624, 0.003603374627089124, 0.003524411278926761, 0.003502337199797772, 0.003474888092128595, 0.0033323999612373477, 0.003216234558647048, 0.003125907798125865, 0.0030747784417396846, 0.0030706027651733227, 0.0030164273548210106, 0.002993139039763192, 0.0029462967083930605, 0.002924666260864965, 0.0029221214819478156, 0.0029128088063254468, 0.002857677751520691, 0.002850668644709742]
# Topic  17 :  [0.0074446984455944195, 0.006650810439242453, 0.005785136195558531, 0.005622804582113301, 0.00531035177830106, 0.005198082123157292, 0.004581368170900549, 0.003683389759447889, 0.003524851638052277, 0.003495690126809143, 0.0034713974382135936, 0.0034627494560908988, 0.0033843639381786837, 0.0033321996242926264, 0.003091005393435136, 0.0029960086903523682, 0.0027373639999571865, 0.002462914820271719, 0.0024587497015977735, 0.0024222580670068697, 0.0023560146020469063, 0.0022196905594012066, 0.0022130294581196638, 0.0022085646828720667, 0.002157080712175864, 0.0021124390244132147, 0.0020857676392416072, 0.002066279678344916, 0.0020513093846716247, 0.0019096093143185406, 0.0019038433832327872, 0.0018795627153927628, 0.001848664978302038, 0.0018373041654363956, 0.0017663954476008603, 0.0017584487136751452, 0.0017296624375768867, 0.0017040065066543956, 0.0016906642325365136, 0.001688630868392738, 0.0016879195727569963, 0.0016708086746404062, 0.0016218852799802447, 0.001610680820485283, 0.0016020251350306349, 0.0016020215860287727, 0.0016000084981157485, 0.0015850829235974106, 0.0015754541004699787, 0.0015621094217006415]
# Topic  18 :  [0.024855278031718636, 0.022794898547107416, 0.015349032052116745, 0.008407933719596361, 0.007418998422497232, 0.007247967255190402, 0.006787307694765865, 0.006549957345585826, 0.006214096257935262, 0.005919390594386694, 0.0056007788487633286, 0.005413852201945092, 0.005399457242150965, 0.004062571755520374, 0.0039037498023581666, 0.0034616159783534828, 0.003436930562969034, 0.003305645763908725, 0.0031917317215398202, 0.003121771609541958, 0.002997298415032291, 0.0029755223540458473, 0.0029534229526446717, 0.002893173331477467, 0.002864512978650674, 0.0028320084288087216, 0.002773250921270794, 0.0027109674145881202, 0.0027009061177328724, 0.0026291612366937697, 0.002591376278543662, 0.002551448551983699, 0.0025346480227414698, 0.0024500742640111996, 0.0024120242391626606, 0.002251611156296897, 0.0022184690632992246, 0.002184874258544812, 0.0021771841696352112, 0.0021664181246055566, 0.002143810738082896, 0.002125324068232731, 0.0021212954831958428, 0.0020994076419880497, 0.002079212728025243, 0.0020294660209387934, 0.0019108651665078274, 0.0019007015218014413, 0.0018949453434863373, 0.0018928408921294448]
# Topic  19 :  [0.6015967498702439, 0.045002587548070454, 0.010930233816793986, 0.010537815845627027, 0.00796018051128359, 0.0071254808540607084, 0.006476826484539297, 0.005580776219008447, 0.0044860803876456985, 0.004399076236917913, 0.004213266471839998, 0.004206002201682512, 0.004052343217431511, 0.003942384216006583, 0.0038981012669081585, 0.003807899368725992, 0.0033724580360634817, 0.003204215478119643, 0.0028164731871761868, 0.002301176564812197, 0.0021823779930271996, 0.002025307355468413, 0.0019429802844986045, 0.001931962955241669, 0.0018800604330645764, 0.001875892450038839, 0.0017829090296097403, 0.0015335238755311215, 0.0012937093328233879, 0.0012269066880843328, 0.0012250732904606956, 0.0011925681119248713, 0.0011716615443928457, 0.001167130948489526, 0.0011637924937473885, 0.0011635667185844248, 0.0011570064131825996, 0.0011468117288762722, 0.0011414470513321639, 0.0011268113387126416, 0.001097471125751668, 0.001049379574936152, 0.0010483951333222293, 0.001047776104047506, 0.0010386701365775177, 0.0010279625354973113, 0.0010276168613781989, 0.0010053403329040045, 0.0009948047658785686, 0.0009745715172821398]

# %%
import nltk
import enchant
d = enchant.Dict("en_US")
def predict_doc_topic(doc, topic_words_dict, topic_words_prob_dict):
    text = nltk.tokenize.word_tokenize(doc)
#     for word in text:
#         if not d.check(word):
#             if len(word) < 4:
#                 text.remove(word)
    temp_dist = nltk.FreqDist(text)
    word_dist = {}
    for word in temp_dist:
        word_dist[word] = temp_dist[word]
#     for word in temp_dist:
#         if word_dist[word] > 10:
#             word_dist.pop(word)
    doc_topics_prob = {}
    for topic in topic_words_dict:
        score = 0
        word_list = topic_words_dict[topic]
        prob_list = topic_words_prob_dict[topic]
        for index in range(len(word_list)):
            if word_list[index] in word_dist:
                score += word_dist[word_list[index]] * prob_list[index]
        doc_topics_prob[topic] = score
    return doc_topics_prob

# %%
docs[27]
# Out:
# "this is hell.  hasn't anyone noticed?"

# %%
new_vectors = []
for doc in docs:
    doc_topic_probs = predict_doc_topic(doc, topic_words_dict, topic_words_prob_dict)
    vector = []
    for i in range(n_components):
        vector.append(doc_topic_probs[i])
    new_vectors.append(vector)

# %%
new_vectors = np.array(new_vectors)

# %%
new_vectors.shape

# %%
clf = mixture.GaussianMixture(n_components=10, covariance_type='full')
print("Creating Mixture object")
clf.fit(new_vectors)
print("Done fitting data")
# Out:
# Creating Mixture object
# Done fitting data

# %%
pred = clf.predict_proba(new_vectors)

# %%
pred.shape
# Out:
# (4491, 10)

# %%
def group_by_label(l):
    it = itertools.groupby(l, operator.itemgetter(1))
    counts = []
    for key, subiter in it:
        counts.append(sum(item[0] for item in subiter))
    return counts

# %%
def compute_homogeneity(preds, labels):
    cluster_label_counts = []
    for pred in preds.transpose():
        cluster_label_counts.append(group_by_label([(p,label) for p,label in zip(pred,labels)]))
    
    entropys = []
    for cluster_label_count in cluster_label_counts:
        entropys.append(scipy.stats.entropy(cluster_label_count))
         
    return np.mean(entropys)

# %%
def compute_completeness(preds, labels, num_clusters, num_labels):
    label_cluster_counts = {label:np.zeros(num_clusters) for label in range(num_labels)}
    
    for pred, label in zip(preds, labels):
        label_cluster_counts[label] = np.sum([label_cluster_counts[label], pred], axis=0)
    
    entropys = []
    for label_cluster_count in label_cluster_counts.values():
        entropys.append(scipy.stats.entropy(label_cluster_count))
          
    return np.mean(entropys)

# %%
def v_measure(preds, labels, num_clusters, num_labels):
    if len(labels) == 0:
        return 1.0, 1.0, 1.0
      
    homogeneity = compute_homogeneity(preds, labels)
    completeness = compute_completeness(preds, labels, num_clusters, num_labels)
    
    if homogeneity==0.0 and completeness==0.0:
        return 0.0, 0.0, 0.0
    v_measure_score = (2.0 * homogeneity * completeness /
                   (homogeneity + completeness))
      
    return homogeneity, completeness, v_measure_score

# %%
topic_label_mapping = {}
label = 0
for topic in set(doc_topics):
    topic_label_mapping[topic] = label
    label += 1

# %%
labels = []
for topic in doc_topics:
    labels.append(topic_label_mapping[topic])

# %%
v_measure(pred, labels, 10, 20)
# Out:
# (1.579257172937448, 1.1403383403493508, 1.3243789341274603)
