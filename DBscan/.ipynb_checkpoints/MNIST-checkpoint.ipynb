# %%
import mnist_reader
from scipy.spatial import distance
import numpy as np

# %%
eps = 7
minPoints = 5

# %%
training_images, training_labels = mnist_reader.load_mnist('data/fashion', kind='train')
test_images, test_labels = mnist_reader.load_mnist('data/fashion', kind='t10k')
images = np.concatenate((training_images, test_images), axis = 0)
labels = np.concatenate((training_labels, test_labels), axis = 0)

# %%
labels
# Out:
# array([5, 0, 4, ..., 4, 5, 6], dtype=uint8)

# %%
numbers = [0 for x in range(10)]
new_images = np.empty((0, 784), int)
new_labels = labels[0]
i = 1
while(i < len(images)):
    numbers[labels[i]] += 1
    if not numbers[labels[i]] >= 2000:
        np.append(new_images, images[i], 0)
        np.append(new_labels, labels[i], 0)
    i += 1
    print(i)

len(images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-1906560d4082> in <module>()
#       7     if not numbers[labels[i]] >= 2000:
#       8         np.append(new_images, images[i], 0)
# ----> 9         np.append(new_labels, labels[i], 0)
#      10     i += 1
#      11     print(i)
#
# /usr/local/lib/python3.6/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    5164         values = ravel(values)
#    5165         axis = arr.ndim-1
# -> 5166     return concatenate((arr, values), axis=axis)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
for i in range(len(training_images)):
    for j in range(len(training_images)):
        print(str(training_lables[i]) + "->" + str(training_lables[j]) + ": " + str(distance.euclidean(training_images[i], training_images[j]) / 256))
# Out:
# 7->7: 0.0
# 7->3: 8.645580560750208
# 7->4: 9.949570720364333
# 7->6: 9.276250757984068
# 7->1: 9.639346837119675
# 7->8: 9.567153496489466
# 7->1: 8.84469286741746
# 7->0: 8.355749067586265
# 7->9: 9.448202973513585
# 7->8: 9.466737841844514
# 7->0: 9.493474224773843
# 7->3: 10.284706717293506
# 7->1: 9.90617606439286
# 7->2: 9.084963404361833
# 7->7: 9.686335142920493
# 7->0: 9.166057867005263
# 7->2: 9.136634412019902
# 7->9: 8.753069529958566
# 7->6: 9.5865821528346
# 7->0: 9.363843459341613
# 7->1: 10.590347328721979
# 7->6: 9.167813131135574
# 7->7: 9.445533819263968
# 7->1: 9.447825864939444
# 7->9: 9.742611163853306
# 7->7: 9.240468656206142
# 7->6: 9.714282220150615
# 7->5: 8.451874871457424
# 7->5: 8.877105033422442
# 7->8: 9.922253314637949
# 7->8: 9.44217227705417
# 7->3: 9.11820835651459
# 7->4: 9.768373050848686
# 7->4: 9.410749708870586
# 7->8: 8.146903693730636
# 7->7: 9.744003408096294
# 7->3: 8.938568691569486
# 7->6: 8.968750850664158
# 7->4: 10.342462096464114
# ...

# %%
for i in range(len(training_images)):
    for j in range(len(training_images)):
        print(str(training_lables[i]) + "->" + str(training_lables[j]) + ": " + str(distance.euclidean(training_images[i], training_images[j])))

# %%
neighbors_dict = {}
def create_neighbors():
    for i in range(len(training_images)):
        point_X = training_images[i]
        for j in range(len(training_images)):
            point_Y = training_images[j]
            if(distance.euclidean(point_X,point_Y) <= eps):
                if(i in neighbors_dict):
                    neighbors_dict[i].append(j)
                else:
                    neighbors_dict[i] = [j]

# %%
create_neighbors()

# %%
visited = []
clusters = {}
noise = []
def dbscan():
    cluster = 0
    for index in range(len(training_images)):
        neighbors = neighbors_dict[index]
        if len(neighbors) < minPoints: 
            noise.append(index)
        else:
            clusters[cluster] = []
            expandCluster(index, neighbors, cluster)
            cluster += 1

# %%
def expandCluster(index, neighbors, cluster):
    while(len(neighbors) != 0):
        point = neighbors.pop(0)
        point = int(point)
        if point not in visited:
            visited.append(point)
            clusters[cluster].append(point)
            potential_cluster_points = neighbors_dict[point]
            neighbors.extend(potential_cluster_points)

# %%
dbscan()
