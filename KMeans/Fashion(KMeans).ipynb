# %%
from scipy.spatial import distance
import numpy as np
import mnist_reader
import math

# %%
training_images, training_labels = mnist_reader.load_mnist('data/fashion', kind='train')
test_images, test_labels = mnist_reader.load_mnist('data/fashion', kind='t10k')
images = np.concatenate((training_images, test_images), axis = 0)
labels = np.concatenate((training_labels, test_labels), axis = 0)

# %%
def get_distance(a,b):
    return distance.euclidean(a,b)

# %%
def make_clusters(images, centroids, k):
    number_of_images = images.shape[0]
    clusters = [[] for i in range(0, k)]

    for i in range(0, number_of_images - 1):
        distances = []
        for j in range(0, k):
            distance = get_distance(images[i], centroids[j])
            distances.append((distance, j))

        distances = sorted(distances)
        cluster_number = distances[0][1]
        clusters[cluster_number].append(i)


    return clusters

# %%
def recalculate_centroids(centroids, clusters):
    for i in range (0, len(clusters)):
        image_list = []
        for image_index in clusters[i]:
            image_list.append(images[image_index])
        np_array = np.array(image_list)
        centroids[i] = np_array.mean(axis = 0)

    return centroids

# %%
def remake_cluster(clusters, centroids):
    
    total_images_reclustered = 0
    for i in range(0, len(clusters)):
        cluster = clusters[i]
        number_of_images_reclustered = 0
        for image_index in cluster:
            distances_to_each_centroid = {}
            for j in range(0 , len(centroids)):
                distance = get_distance(images[image_index], centroids[j])
                distances_to_each_centroid[j] = distance

            min_distance = distances_to_each_centroid[0]
            min_distance_index = 0
            for cluster_no in distances_to_each_centroid.keys():
                if distances_to_each_centroid[cluster_no] < min_distance:
                    min_distance = distances_to_each_centroid[cluster_no]
                    min_distance_index = cluster_no
            if min_distance_index != i:
                clusters[i].remove(image_index)
                clusters[min_distance_index].append(image_index)
                change_occured = True
                number_of_images_reclustered += 1
        total_images_reclustered += number_of_images_reclustered
    return clusters, total_images_reclustered

# %%
def calculate_purity_of_clusters(clusters, k):
    total_purity = 0
    for i in range(0, len(clusters)):
        purity = purity_of_cluster(clusters[i])
#         print("Purity: " + str(purity))
        total_purity += purity
    total_purity = total_purity / len(images)
    return total_purity

# %%
def purity_of_cluster(cluster):
    label_occurance = {}
    for image_index in cluster:
        label = labels[image_index]
        if label in label_occurance:
            label_occurance[label] += 1
        else:
            label_occurance[label] = 1
    majority_label = ""
    max_occurance = 0
    for label in label_occurance.keys():
        if label_occurance[label] > max_occurance:
            max_occurance = label_occurance[label]
            majority_label = label
    
    majority_count = 0
    for image_index in cluster:
        if labels[image_index] == majority_label:
            majority_count += 1
    
    return majority_count

# %%
def calculate_gini_index(clusters):
    gini_total = 0
    for cluster in clusters:
        cluster_gini = 1
        image_index_count = create_image_index_count_dict(cluster)
        for label in image_index_count.keys():
            cluster_gini = cluster_gini - math.pow((image_index_count[label] / len(cluster)) , 2)
        gini_total += cluster_gini * len(cluster)
    
    return gini_total / len(images)

# %%
def create_image_index_count_dict(cluster):
    image_index_count = {}
    for image_index in cluster:
        label = labels[image_index]
        if label in image_index_count:
            image_index_count[label] += 1
        else:
            image_index_count[label] = 1
    return image_index_count

# %%
def KMeans(k):

    number_of_images = images.shape[0]

    centroid_indexs = np.linspace(0, number_of_images-1, k)
    centroid_indexs = list(map(int, centroid_indexs))

    centroids = []
    for i in range(0, len(centroid_indexs)):
        centroids.append(images[centroid_indexs[i]])
    # initial clusters
    clusters = make_clusters(images, centroids, k)

    iterate = True
    while(iterate):
        centroids = recalculate_centroids(centroids, clusters)
        clusters, total_images_reclustered = remake_cluster(clusters, centroids)
        purity_of_clusters = calculate_purity_of_clusters(clusters, k)
        gini_index = calculate_gini_index(clusters)
        print("Purity of cluster: " + str(purity_of_clusters))
        print("Gini index: " + str(gini_index))
        print("Total images reclustered: " + str(total_images_reclustered))
        print()
        
        if total_images_reclustered == 0:
            iterate = False
            
    return clusters

# %%
print("Starting KMeans.........\n")
clusters = KMeans(10)
print("Done")
# Out:
# Starting KMeans.........
#
# Purity of cluster: 0.35754285714285716
# Gini index: 0.7476871806430206
# Total images reclustered: 19337
#
# Purity of cluster: 0.40114285714285713
# Gini index: 0.7065730706472088
# Total images reclustered: 11236
#
# Purity of cluster: 0.43
# Gini index: 0.6754671058825736
# Total images reclustered: 7119
#
# Purity of cluster: 0.45094285714285715
# Gini index: 0.6495364553702704
# Total images reclustered: 5040
#
# Purity of cluster: 0.4689714285714286
# Gini index: 0.6293112019552598
# Total images reclustered: 4000
#
# Purity of cluster: 0.48684285714285713
# Gini index: 0.6119093125266154
# Total images reclustered: 3572
#
# Purity of cluster: 0.5029142857142858
# Gini index: 0.5962686092966007
# Total images reclustered: 3290
#
# Purity of cluster: 0.5169285714285714
# Gini index: 0.5827694192658567
# Total images reclustered: 3147
#
# Purity of cluster: 0.5281857142857143
# Gini index: 0.5735937099050163
# Total images reclustered: 2954
#
# Purity of cluster: 0.5354285714285715
# Gini index: 0.5678352411740929
# Total images reclustered: 2847
#
# Purity of cluster: 0.5393571428571429
# Gini index: 0.5634996848700975
# Total images reclustered: 2675
#
# Purity of cluster: 0.5462428571428571
# Gini index: 0.5592597262161113
# Total images reclustered: 2545
#
# Purity of cluster: 0.5559142857142857
# Gini index: 0.5556043552769022
# Total images reclustered: 2379
#
# Purity of cluster: 0.5647142857142857
# Gini index: 0.5517930110920871
# Total images reclustered: 2237
#
# Purity of cluster: 0.5726714285714286
# Gini index: 0.5476332715865396
# Total images reclustered: 1998
#
# Purity of cluster: 0.5790142857142857
# Gini index: 0.5445043104418398
# Total images reclustered: 1838
#
# Purity of cluster: 0.5838857142857143
# Gini index: 0.5422401397444779
# Total images reclustered: 1589
#
# Purity of cluster: 0.5873857142857143
# Gini index: 0.5403576448075116
# Total images reclustered: 1380
#
# Purity of cluster: 0.5894857142857143
# Gini index: 0.5393945449971171
# Total images reclustered: 1268
#
# Purity of cluster: 0.5909428571428571
# Gini index: 0.5386667237219457
# Total images reclustered: 1094
#
# Purity of cluster: 0.5920285714285715
# Gini index: 0.5377857551939564
# Total images reclustered: 915
#
# Purity of cluster: 0.5926857142857143
# Gini index: 0.5374292683008055
# Total images reclustered: 830
#
# Purity of cluster: 0.5926428571428571
# Gini index: 0.5374903713724182
# Total images reclustered: 743
#
# Purity of cluster: 0.5924571428571429
# Gini index: 0.5373488732547594
# Total images reclustered: 622
#
# Purity of cluster: 0.5920857142857143
# Gini index: 0.5374335246760761
# Total images reclustered: 591
#
# Purity of cluster: 0.5915142857142857
# Gini index: 0.5375166664488709
# Total images reclustered: 537
#
# Purity of cluster: 0.5907142857142857
# Gini index: 0.5378509349776949
# Total images reclustered: 523
#
# Purity of cluster: 0.5898
# Gini index: 0.5382755505006952
# Total images reclustered: 507
#
# Purity of cluster: 0.5892428571428572
# Gini index: 0.5382877630028231
# Total images reclustered: 470
#
# Purity of cluster: 0.5881714285714286
# Gini index: 0.5387650323573243
# Total images reclustered: 421
#
# Purity of cluster: 0.5874428571428572
# Gini index: 0.5388589227797169
# Total images reclustered: 388
#
# Purity of cluster: 0.5865714285714285
# Gini index: 0.5388594155570549
# Total images reclustered: 363
#
# Purity of cluster: 0.5855857142857143
# Gini index: 0.5392955762341012
# Total images reclustered: 353
#
# Purity of cluster: 0.5848428571428571
# Gini index: 0.5396004228006476
# Total images reclustered: 352
#
# Purity of cluster: 0.5849
# Gini index: 0.5400509730110356
# Total images reclustered: 335
#
# Purity of cluster: 0.5847714285714286
# Gini index: 0.5406825886653599
# Total images reclustered: 322
#
# Purity of cluster: 0.5846285714285714
# Gini index: 0.5411696306389313
# Total images reclustered: 311
#
# Purity of cluster: 0.5846714285714286
# Gini index: 0.5416474904220882
# Total images reclustered: 293
#
# Purity of cluster: 0.5845142857142858
# Gini index: 0.5422013315049056
# Total images reclustered: 295
#
# Purity of cluster: 0.5845
# Gini index: 0.5428195947965695
# Total images reclustered: 294
#
# Purity of cluster: 0.5843142857142857
# Gini index: 0.5435289058022413
# Total images reclustered: 316
#
# Purity of cluster: 0.5845428571428571
# Gini index: 0.5436232655502669
# Total images reclustered: 318
#
# Purity of cluster: 0.5843
# Gini index: 0.544085075130961
# Total images reclustered: 300
#
# Purity of cluster: 0.5841714285714286
# Gini index: 0.544381520660447
# Total images reclustered: 272
#
# Purity of cluster: 0.5845571428571429
# Gini index: 0.5444878647703636
# Total images reclustered: 267
#
# Purity of cluster: 0.5844571428571429
# Gini index: 0.5446367170606481
# Total images reclustered: 276
#
# Purity of cluster: 0.5842857142857143
# Gini index: 0.5449034031060156
# Total images reclustered: 279
#
# Purity of cluster: 0.5842714285714286
# Gini index: 0.545053171356452
# Total images reclustered: 242
#
# Purity of cluster: 0.5840428571428572
# Gini index: 0.5452882432201477
# Total images reclustered: 232
#
# Purity of cluster: 0.5839428571428571
# Gini index: 0.5454074103423056
# Total images reclustered: 236
#
# Purity of cluster: 0.5837857142857142
# Gini index: 0.5456531874402175
# Total images reclustered: 209
#
# Purity of cluster: 0.5837714285714286
# Gini index: 0.5457585939611496
# Total images reclustered: 210
#
# Purity of cluster: 0.5836714285714286
# Gini index: 0.5458623817166951
# Total images reclustered: 189
#
# Purity of cluster: 0.5835
# Gini index: 0.5459554387512978
# Total images reclustered: 176
#
# Purity of cluster: 0.5836
# Gini index: 0.5458467836917107
# Total images reclustered: 144
#
# Purity of cluster: 0.5835714285714285
# Gini index: 0.545849534880238
# Total images reclustered: 153
#
# Purity of cluster: 0.5835714285714285
# Gini index: 0.5458579568642422
# Total images reclustered: 132
#
# Purity of cluster: 0.5837571428571429
# Gini index: 0.5457109053291082
# Total images reclustered: 134
#
# Purity of cluster: 0.5837428571428571
# Gini index: 0.5456836824213603
# Total images reclustered: 129
#
# Purity of cluster: 0.5837857142857142
# Gini index: 0.5456214704366502
# Total images reclustered: 113
#
# Purity of cluster: 0.5839142857142857
# Gini index: 0.5454286969568202
# Total images reclustered: 119
#
# Purity of cluster: 0.5840857142857143
# Gini index: 0.5451970941816615
# Total images reclustered: 116
#
# Purity of cluster: 0.5841714285714286
# Gini index: 0.5450568839998431
# Total images reclustered: 115
#
# Purity of cluster: 0.5843
# Gini index: 0.5448111995926106
# Total images reclustered: 94
#
# Purity of cluster: 0.5843571428571429
# Gini index: 0.5446902461382537
# Total images reclustered: 66
#
# Purity of cluster: 0.5845142857142858
# Gini index: 0.5445866119142354
# Total images reclustered: 68
#
# Purity of cluster: 0.5845857142857143
# Gini index: 0.544483530193935
# Total images reclustered: 58
#
# Purity of cluster: 0.5846714285714286
# Gini index: 0.5443340751895631
# Total images reclustered: 67
#
# Purity of cluster: 0.5846142857142858
# Gini index: 0.5443285200115643
# Total images reclustered: 60
#
# Purity of cluster: 0.5845714285714285
# Gini index: 0.544250550830433
# Total images reclustered: 61
#
# Purity of cluster: 0.5844857142857143
# Gini index: 0.5441471762217682
# Total images reclustered: 70
#
# Purity of cluster: 0.5844285714285714
# Gini index: 0.5440667640852623
# Total images reclustered: 74
#
# Purity of cluster: 0.5842571428571428
# Gini index: 0.5440505811074083
# Total images reclustered: 72
#
# Purity of cluster: 0.5841142857142857
# Gini index: 0.5439726636961254
# Total images reclustered: 74
#
# Purity of cluster: 0.5840428571428572
# Gini index: 0.5438277058517341
# Total images reclustered: 92
#
# Purity of cluster: 0.5838285714285715
# Gini index: 0.543907109489692
# Total images reclustered: 78
#
# Purity of cluster: 0.5839142857142857
# Gini index: 0.543702932096444
# Total images reclustered: 68
#
# Purity of cluster: 0.5838428571428571
# Gini index: 0.5436332975311665
# Total images reclustered: 76
#
# Purity of cluster: 0.5837
# Gini index: 0.543615642200939
# Total images reclustered: 74
#
# Purity of cluster: 0.5836857142857143
# Gini index: 0.5435118905544878
# Total images reclustered: 65
#
# Purity of cluster: 0.5836714285714286
# Gini index: 0.5434150377195643
# Total images reclustered: 58
#
# Purity of cluster: 0.5836428571428571
# Gini index: 0.5433467060208765
# Total images reclustered: 60
#
# Purity of cluster: 0.5836
# Gini index: 0.5432612995662186
# Total images reclustered: 57
# Purity of cluster: 0.5836428571428571
# Gini index: 0.5431756765928036
# Total images reclustered: 45
#
# Purity of cluster: 0.5836714285714286
# Gini index: 0.5431763402711506
# Total images reclustered: 45
#
# Purity of cluster: 0.5838
# Gini index: 0.5430680493343226
# Total images reclustered: 38
#
# Purity of cluster: 0.584
# Gini index: 0.5429046723289654
# Total images reclustered: 39
#
# Purity of cluster: 0.5841571428571428
# Gini index: 0.5428750178024627
# Total images reclustered: 49
#
# Purity of cluster: 0.5842714285714286
# Gini index: 0.5428164800190733
# Total images reclustered: 51
#
# Purity of cluster: 0.5844428571428572
# Gini index: 0.5426798549365279
# Total images reclustered: 44
#
# Purity of cluster: 0.5846571428571429
# Gini index: 0.5425003217071769
# Total images reclustered: 34
#
# Purity of cluster: 0.5847714285714286
# Gini index: 0.5423991330235655
# Total images reclustered: 30
#
# Purity of cluster: 0.5848714285714286
# Gini index: 0.5423542330619389
# Total images reclustered: 21
#
# Purity of cluster: 0.5849142857142857
# Gini index: 0.5423630231412689
# Total images reclustered: 15
#
# Purity of cluster: 0.585
# Gini index: 0.5422903673428421
# Total images reclustered: 15
#
# Purity of cluster: 0.5850285714285715
# Gini index: 0.542257515147729
# Total images reclustered: 5
#
# Purity of cluster: 0.5850142857142857
# Gini index: 0.5422778979252395
# Total images reclustered: 2
#
# Purity of cluster: 0.5850142857142857
# Gini index: 0.5422755403000259
# Total images reclustered: 2
#
# Purity of cluster: 0.585
# Gini index: 0.5422873083878316
# Total images reclustered: 1
#
# Purity of cluster: 0.5849857142857143
# Gini index: 0.5422990706955155
# Total images reclustered: 1
#
# Purity of cluster: 0.5849714285714286
# Gini index: 0.54230348836954
# Total images reclustered: 3
#
# Purity of cluster: 0.5849285714285715
# Gini index: 0.5423424844937912
# Total images reclustered: 3
#
# Purity of cluster: 0.5849428571428571
# Gini index: 0.5423305949718694
# Total images reclustered: 2
#
# Purity of cluster: 0.5849428571428571
# Gini index: 0.5423314077080391
# Total images reclustered: 1
#
# Purity of cluster: 0.5849428571428571
# Gini index: 0.5423413875553177
# Total images reclustered: 1
#
# Purity of cluster: 0.5849428571428571
# Gini index: 0.5423413875553177
# Total images reclustered: 0
#
#
# Done

# %%
print("Starting KMeans.........\n")
clusters = KMeans(5)
print("Done")
# Out:
# Starting KMeans.........
#
# Purity of cluster: 0.25524285714285716
# Gini index: 0.812659995983776
# Total images reclustered: 19493
#
# Purity of cluster: 0.2891142857142857
# Gini index: 0.7893106705108118
# Total images reclustered: 12603
#
# Purity of cluster: 0.31538571428571427
# Gini index: 0.7778977188847753
# Total images reclustered: 8444
#
# Purity of cluster: 0.3296857142857143
# Gini index: 0.7703998085916869
# Total images reclustered: 5800
#
# Purity of cluster: 0.34127142857142856
# Gini index: 0.7634925447944679
# Total images reclustered: 4197
#
# Purity of cluster: 0.3502142857142857
# Gini index: 0.7573297592663034
# Total images reclustered: 3386
#
# Purity of cluster: 0.3575714285714286
# Gini index: 0.7510406072315362
# Total images reclustered: 2871
#
# Purity of cluster: 0.3626
# Gini index: 0.74506776577804
# Total images reclustered: 2565
#
# Purity of cluster: 0.37011428571428573
# Gini index: 0.738966659857378
# Total images reclustered: 2281
#
# Purity of cluster: 0.3775428571428571
# Gini index: 0.7334895060367163
# Total images reclustered: 1898
#
# Purity of cluster: 0.38267142857142855
# Gini index: 0.7289566311882971
# Total images reclustered: 1522
#
# Purity of cluster: 0.38594285714285714
# Gini index: 0.7261144577834301
# Total images reclustered: 1209
#
# Purity of cluster: 0.3879714285714286
# Gini index: 0.724538605543821
# Total images reclustered: 877
#
# Purity of cluster: 0.38945714285714284
# Gini index: 0.7237480346061277
# Total images reclustered: 679
#
# Purity of cluster: 0.3903857142857143
# Gini index: 0.7234796224472164
# Total images reclustered: 506
#
# Purity of cluster: 0.3911
# Gini index: 0.7234677400294095
# Total images reclustered: 366
#
# Purity of cluster: 0.3917
# Gini index: 0.7234891608906793
# Total images reclustered: 268
#
# Purity of cluster: 0.39212857142857144
# Gini index: 0.7235560214514282
# Total images reclustered: 216
#
# Purity of cluster: 0.3927
# Gini index: 0.7236860893965451
# Total images reclustered: 205
#
# Purity of cluster: 0.3931428571428571
# Gini index: 0.7238787225715199
# Total images reclustered: 186
#
# Purity of cluster: 0.39344285714285715
# Gini index: 0.7241574653415362
# Total images reclustered: 191
#
# Purity of cluster: 0.394
# Gini index: 0.7243479385149564
# Total images reclustered: 220
#
# Purity of cluster: 0.3945142857142857
# Gini index: 0.7243801293747211
# Total images reclustered: 192
#
# Purity of cluster: 0.3948285714285714
# Gini index: 0.7244617032739353
# Total images reclustered: 171
#
# Purity of cluster: 0.39534285714285716
# Gini index: 0.7245027331975359
# Total images reclustered: 182
#
# Purity of cluster: 0.3955714285714286
# Gini index: 0.7247473505299191
# Total images reclustered: 189
#
# Purity of cluster: 0.3959285714285714
# Gini index: 0.7248201906217007
# Total images reclustered: 185
#
# Purity of cluster: 0.39635714285714285
# Gini index: 0.724960471475565
# Total images reclustered: 197
#
# Purity of cluster: 0.3967
# Gini index: 0.7251007461859176
# Total images reclustered: 177
#
# Purity of cluster: 0.3971857142857143
# Gini index: 0.7252330121344951
# Total images reclustered: 173
#
# Purity of cluster: 0.39758571428571426
# Gini index: 0.7253864148780641
# Total images reclustered: 180
#
# Purity of cluster: 0.3981
# Gini index: 0.7253912134250449
# Total images reclustered: 216
#
# Purity of cluster: 0.39852857142857145
# Gini index: 0.7255046523998061
# Total images reclustered: 214
#
# Purity of cluster: 0.39904285714285714
# Gini index: 0.7256181764921713
# Total images reclustered: 222
#
# Purity of cluster: 0.39958571428571427
# Gini index: 0.7257426537202648
# Total images reclustered: 214
#
# Purity of cluster: 0.4003285714285714
# Gini index: 0.7257176623667821
# Total images reclustered: 259
#
# Purity of cluster: 0.4009
# Gini index: 0.7258198215949371
# Total images reclustered: 267
#
# Purity of cluster: 0.4014
# Gini index: 0.7259711561007458
# Total images reclustered: 300
#
# Purity of cluster: 0.40181428571428573
# Gini index: 0.7261033547564352
# Total images reclustered: 304
#
# Purity of cluster: 0.4025714285714286
# Gini index: 0.7260233577835774
# Total images reclustered: 350
#
# Purity of cluster: 0.40308571428571427
# Gini index: 0.7260124441019216
# Total images reclustered: 361
#
# Purity of cluster: 0.40395714285714285
# Gini index: 0.7257471848490233
# Total images reclustered: 385
#
# Purity of cluster: 0.40475714285714287
# Gini index: 0.7253978261885807
# Total images reclustered: 422
#
# Purity of cluster: 0.40567142857142857
# Gini index: 0.7249801583144863
# Total images reclustered: 515
#
# Purity of cluster: 0.4065142857142857
# Gini index: 0.7245999847967812
# Total images reclustered: 591
#
# Purity of cluster: 0.40754285714285715
# Gini index: 0.7237006346773028
# Total images reclustered: 691
#
# Purity of cluster: 0.4088
# Gini index: 0.7225485319349386
# Total images reclustered: 841
#
# Purity of cluster: 0.40995714285714285
# Gini index: 0.7209751645511896
# Total images reclustered: 1015
#
# Purity of cluster: 0.4116
# Gini index: 0.7185140188050252
# Total images reclustered: 1158
#
# Purity of cluster: 0.4165142857142857
# Gini index: 0.7155811584821404
# Total images reclustered: 1219
#
# Purity of cluster: 0.4224
# Gini index: 0.7122352315920024
# Total images reclustered: 1362
#
# Purity of cluster: 0.42778571428571427
# Gini index: 0.7085257207800706
# Total images reclustered: 1366
#
# Purity of cluster: 0.43301428571428574
# Gini index: 0.7043547689859131
# Total images reclustered: 1389
#
# Purity of cluster: 0.43767142857142854
# Gini index: 0.6998608747028414
# Total images reclustered: 1410
#
# Purity of cluster: 0.4417857142857143
# Gini index: 0.6953621619124934
# Total images reclustered: 1376
#
# Purity of cluster: 0.44484285714285715
# Gini index: 0.6915578357045711
# Total images reclustered: 1326
#
# Purity of cluster: 0.44765714285714286
# Gini index: 0.6879377414316409
# Total images reclustered: 1230
#
# Purity of cluster: 0.44985714285714284
# Gini index: 0.6845874004611183
# Total images reclustered: 1150
#
# Purity of cluster: 0.4517285714285714
# Gini index: 0.68153886401594
# Total images reclustered: 1170
#
# Purity of cluster: 0.45321428571428574
# Gini index: 0.6784416834041564
# Total images reclustered: 1146
#
# Purity of cluster: 0.45445714285714284
# Gini index: 0.6750565087341808
# Total images reclustered: 1169
#
# Purity of cluster: 0.45502857142857145
# Gini index: 0.6717593473057923
# Total images reclustered: 1081
#
# Purity of cluster: 0.4549142857142857
# Gini index: 0.6693477621400219
# Total images reclustered: 1002
#
# Purity of cluster: 0.4545142857142857
# Gini index: 0.667295551499753
# Total images reclustered: 841
#
# Purity of cluster: 0.45448571428571427
# Gini index: 0.6651314521481444
# Total images reclustered: 701
#
# Purity of cluster: 0.45424285714285717
# Gini index: 0.6634404644547982
# Total images reclustered: 611
#
# Purity of cluster: 0.4538142857142857
# Gini index: 0.6621193511230192
# Total images reclustered: 519
#
# Purity of cluster: 0.4535142857142857
# Gini index: 0.6610637495354138
# Total images reclustered: 424
#
# Purity of cluster: 0.4532857142857143
# Gini index: 0.6602809394834753
# Total images reclustered: 340
#
# Purity of cluster: 0.4531428571428571
# Gini index: 0.6595590382645228
# Total images reclustered: 290
#
# Purity of cluster: 0.4531
# Gini index: 0.6589752302332105
# Total images reclustered: 227
#
# Purity of cluster: 0.45285714285714285
# Gini index: 0.6588123160924955
# Total images reclustered: 173
#
# Purity of cluster: 0.4529142857142857
# Gini index: 0.658423858548822
# Total images reclustered: 123
#
# Purity of cluster: 0.45274285714285717
# Gini index: 0.658434258428208
# Total images reclustered: 104
#
# Purity of cluster: 0.45267142857142856
# Gini index: 0.658416846260547
# Total images reclustered: 70
#
# Purity of cluster: 0.4525571428571429
# Gini index: 0.6584434398931319
# Total images reclustered: 53
#
# Purity of cluster: 0.4525142857142857
# Gini index: 0.6584143356104749
# Total images reclustered: 33
#
# Purity of cluster: 0.4525142857142857
# Gini index: 0.658329567367953
# Total images reclustered: 27
#
# Purity of cluster: 0.45248571428571427
# Gini index: 0.6583131477539341
# Total images reclustered: 13
#
# Purity of cluster: 0.4524714285714286
# Gini index: 0.6583369803079911
# Total images reclustered: 4
#
# Purity of cluster: 0.4524714285714286
# Gini index: 0.6583441591796692
# Total images reclustered: 1
#
# Purity of cluster: 0.4524714285714286
# Gini index: 0.6583441591796692
# Total images reclustered: 0
#
# Done

# %%
print("Starting KMeans.........\n")
clusters = KMeans(20)
print("Done")
# Out:
# Starting KMeans.........
#
# Purity of cluster: 0.5351142857142858
# Gini index: 0.6034197890197003
# Total images reclustered: 20264
#
# Purity of cluster: 0.6016
# Gini index: 0.5315158407222228
# Total images reclustered: 13070
#
# Purity of cluster: 0.6455714285714286
# Gini index: 0.4818663394844875
# Total images reclustered: 9137
#
# Purity of cluster: 0.6791
# Gini index: 0.4453557937701466
# Total images reclustered: 6552
#
# Purity of cluster: 0.6976571428571429
# Gini index: 0.4229026952012545
# Total images reclustered: 4804
#
# Purity of cluster: 0.7044857142857143
# Gini index: 0.41264606397049697
# Total images reclustered: 3703
#
# Purity of cluster: 0.7053285714285714
# Gini index: 0.40845959897414374
# Total images reclustered: 3129
#
# Purity of cluster: 0.7038571428571428
# Gini index: 0.4061683309138223
# Total images reclustered: 2671
#
# Purity of cluster: 0.7016857142857142
# Gini index: 0.40358850325543205
# Total images reclustered: 2221
#
# Purity of cluster: 0.7028571428571428
# Gini index: 0.4020115205670585
# Total images reclustered: 1797
#
# Purity of cluster: 0.7028
# Gini index: 0.4008079262768467
# Total images reclustered: 1444
#
# Purity of cluster: 0.7025714285714286
# Gini index: 0.3996930576073632
# Total images reclustered: 1137
#
# Purity of cluster: 0.7018857142857143
# Gini index: 0.3993130439767671
# Total images reclustered: 921
#
# Purity of cluster: 0.7028857142857143
# Gini index: 0.39858187716801796
# Total images reclustered: 785
#
# Purity of cluster: 0.7032142857142857
# Gini index: 0.39914248162052807
# Total images reclustered: 696
#
# Purity of cluster: 0.7040714285714286
# Gini index: 0.3986230496531025
# Total images reclustered: 620
#
# Purity of cluster: 0.7042428571428572
# Gini index: 0.39845330432609344
# Total images reclustered: 610
#
# Purity of cluster: 0.7039571428571428
# Gini index: 0.3983408927523952
# Total images reclustered: 574
#
# Purity of cluster: 0.7035571428571429
# Gini index: 0.39824498853100415
# Total images reclustered: 550
#
# Purity of cluster: 0.7032571428571428
# Gini index: 0.3980585859517734
# Total images reclustered: 549
#
# Purity of cluster: 0.7029571428571428
# Gini index: 0.39753137246972964
# Total images reclustered: 546
#
# Purity of cluster: 0.7025285714285714
# Gini index: 0.3974125230040095
# Total images reclustered: 542
#
# Purity of cluster: 0.7021
# Gini index: 0.3972001647552906
# Total images reclustered: 552
#
# Purity of cluster: 0.7016285714285714
# Gini index: 0.3968784326066755
# Total images reclustered: 587
#
# Purity of cluster: 0.7012428571428572
# Gini index: 0.39673391297532107
# Total images reclustered: 578
#
# Purity of cluster: 0.7009857142857143
# Gini index: 0.3966067965733835
# Total images reclustered: 603
#
# Purity of cluster: 0.7011714285714286
# Gini index: 0.39638059072487275
# Total images reclustered: 560
#
# Purity of cluster: 0.7009714285714286
# Gini index: 0.39618881411158535
# Total images reclustered: 521
#
# Purity of cluster: 0.7004142857142858
# Gini index: 0.39625758177459586
# Total images reclustered: 560
#
# Purity of cluster: 0.6995857142857143
# Gini index: 0.3965141730735622
# Total images reclustered: 593
#
# Purity of cluster: 0.6988285714285715
# Gini index: 0.3965651778561659
# Total images reclustered: 588
#
# Purity of cluster: 0.6982
# Gini index: 0.3965175292990238
# Total images reclustered: 581
#
# Purity of cluster: 0.6985857142857143
# Gini index: 0.39661313123542175
# Total images reclustered: 590
#
# Purity of cluster: 0.6993
# Gini index: 0.39688752145349876
# Total images reclustered: 576
#
# Purity of cluster: 0.7003285714285714
# Gini index: 0.39690066358252507
# Total images reclustered: 569
#
# Purity of cluster: 0.7017428571428571
# Gini index: 0.396486810127817
# Total images reclustered: 522
#
# Purity of cluster: 0.7032142857142857
# Gini index: 0.39598424706154517
# Total images reclustered: 567
#
# Purity of cluster: 0.7041714285714286
# Gini index: 0.3958114814155598
# Total images reclustered: 548
#
# Purity of cluster: 0.7051857142857143
# Gini index: 0.39572904041597906
# Total images reclustered: 566
#
# Purity of cluster: 0.7063571428571429
# Gini index: 0.39514592691894895
# Total images reclustered: 538
#
# Purity of cluster: 0.7079285714285715
# Gini index: 0.3950514165279727
# Total images reclustered: 531
#
# Purity of cluster: 0.7092285714285714
# Gini index: 0.3950314298379585
# Total images reclustered: 482
#
# Purity of cluster: 0.7106571428571429
# Gini index: 0.3947888552991108
# Total images reclustered: 422
#
# Purity of cluster: 0.7116428571428571
# Gini index: 0.3948982633581983
# Total images reclustered: 416
#
# Purity of cluster: 0.7130142857142857
# Gini index: 0.39466983610582135
# Total images reclustered: 405
#
# Purity of cluster: 0.7143
# Gini index: 0.3946270382609701
# Total images reclustered: 422
#
# Purity of cluster: 0.7155142857142858
# Gini index: 0.3943069913153481
# Total images reclustered: 419
#
# Purity of cluster: 0.7167857142857142
# Gini index: 0.39409832014454543
# Total images reclustered: 421
#
# Purity of cluster: 0.7180428571428571
# Gini index: 0.39402298625360016
# Total images reclustered: 437
#
# Purity of cluster: 0.7193142857142857
# Gini index: 0.3934043601026922
# Total images reclustered: 412
#
# Purity of cluster: 0.7205142857142857
# Gini index: 0.3930523791856173
# Total images reclustered: 385
#
# Purity of cluster: 0.7219
# Gini index: 0.3923014998406283
# Total images reclustered: 391
#
# Purity of cluster: 0.7228
# Gini index: 0.39189984971411973
# Total images reclustered: 365
#
# Purity of cluster: 0.7235285714285714
# Gini index: 0.39171284494575775
# Total images reclustered: 341
#
# Purity of cluster: 0.7244285714285714
# Gini index: 0.391398736523656
# Total images reclustered: 395
#
# Purity of cluster: 0.7249857142857142
# Gini index: 0.3911141356225653
# Total images reclustered: 346
#
# Purity of cluster: 0.7262
# Gini index: 0.39037662197668727
# Total images reclustered: 306
#
# Purity of cluster: 0.7269714285714286
# Gini index: 0.3899007705073414
# Total images reclustered: 286
#
# Purity of cluster: 0.7274142857142857
# Gini index: 0.3896653984074213
# Total images reclustered: 248
#
# Purity of cluster: 0.7278857142857142
# Gini index: 0.38944791404507734
# Total images reclustered: 217
#
# Purity of cluster: 0.7282714285714286
# Gini index: 0.38924748324759534
# Total images reclustered: 198
#
# Purity of cluster: 0.7286
# Gini index: 0.3889687220472324
# Total images reclustered: 192
#
# Purity of cluster: 0.7289857142857142
# Gini index: 0.3886946510155591
# Total images reclustered: 169
#
# Purity of cluster: 0.7292285714285714
# Gini index: 0.38852198221608486
# Total images reclustered: 144
#
# Purity of cluster: 0.7293428571428572
# Gini index: 0.3884397416455425
# Total images reclustered: 125
#
# Purity of cluster: 0.7296285714285714
# Gini index: 0.3881627758371137
# Total images reclustered: 107
#
# Purity of cluster: 0.7298571428571429
# Gini index: 0.3879525326023458
# Total images reclustered: 91
#
# Purity of cluster: 0.7300142857142857
# Gini index: 0.38784726794048535
# Total images reclustered: 94
#
# Purity of cluster: 0.7301857142857143
# Gini index: 0.3877379710011555
# Total images reclustered: 77
#
# Purity of cluster: 0.7303142857142857
# Gini index: 0.38763826386544903
# Total images reclustered: 63
#
# Purity of cluster: 0.7304142857142857
# Gini index: 0.38755660071434783
# Total images reclustered: 60
#
# Purity of cluster: 0.7305571428571429
# Gini index: 0.3874160761346111
# Total images reclustered: 42
#
# Purity of cluster: 0.7306428571428571
# Gini index: 0.3873308231816329
# Total images reclustered: 33
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.3872586585183839
# Total images reclustered: 29
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.38730105966606804
# Total images reclustered: 25
#
# Purity of cluster: 0.7307857142857143
# Gini index: 0.3872507154004125
# Total images reclustered: 15
#
# Purity of cluster: 0.7307857142857143
# Gini index: 0.38722570750931895
# Total images reclustered: 11
#
# Purity of cluster: 0.7307857142857143
# Gini index: 0.38717106166056797
# Total images reclustered: 10
#
# Purity of cluster: 0.7307857142857143
# Gini index: 0.38716341636674423
# Total images reclustered: 7
#
# Purity of cluster: 0.7307857142857143
# Gini index: 0.3871461928883359
# Total images reclustered: 13
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.38723050410310783
# Total images reclustered: 9
#
# Purity of cluster: 0.7307
# Gini index: 0.3872636398059901
# Total images reclustered: 15
#
# Purity of cluster: 0.7307142857142858
# Gini index: 0.38727848554257116
# Total images reclustered: 17
# Purity of cluster: 0.7307
# Gini index: 0.38730124126511684
# Total images reclustered: 9
#
# Purity of cluster: 0.7306857142857143
# Gini index: 0.3873249768804989
# Total images reclustered: 9
#
# Purity of cluster: 0.7306857142857143
# Gini index: 0.38730959522028763
# Total images reclustered: 9
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.38724227612869466
# Total images reclustered: 9
#
# Purity of cluster: 0.7307142857142858
# Gini index: 0.3872514709611897
# Total images reclustered: 8
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.3872398725338756
# Total images reclustered: 2
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.3872435091979794
# Total images reclustered: 4
#
# Purity of cluster: 0.7307285714285714
# Gini index: 0.3872312753351585
# Total images reclustered: 3
#
# Purity of cluster: 0.7307142857142858
# Gini index: 0.38723784067635436
# Total images reclustered: 1
#
# Purity of cluster: 0.7307142857142858
# Gini index: 0.38723784067635436
# Total images reclustered: 0
#
# Done
